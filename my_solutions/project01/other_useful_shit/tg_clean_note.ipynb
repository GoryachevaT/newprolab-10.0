# %%
import datetime, re, os, sys, json, pickle 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#from bs4 import BeautifulSoup as bs

#import requests
#import lxml.html

from scipy import sparse
#import lightgbm as lgb

from functions import dict_gender_to_gendercategory
from functions import dict_age_to_agecategory
from functions import dict_gendercategory_to_gender
from functions import dict_agecategory_to_age

from functions import load_user_json
from functions import url2domain
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

from collections import Counter

import pymystem3
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet, stopwords

from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, RandomizedSearchCV

# %%
#https://bigartm.readthedocs.io/en/stable/installation/linux.html
import artm

# %%
import gc
gc.collect()
# Out:
# 7

# %% [markdown]
# ## read data + basic features

# %%
# %%time

file_path = '../data/share/project01/gender_age_dataset.txt'
df = pd.read_csv(file_path, sep='\t')
# Out:
# CPU times: user 8.28 s, sys: 1.59 s, total: 9.88 s
# Wall time: 10.7 s

# %%
# %%time

df['user_json'] = load_user_json(df['user_json'])
df['domain_list'] = df['user_json'].map(lambda x: [url2domain(visit['url']) for visit in x['visits']])
df['norm_domain_list'] = df['domain_list'].apply(lambda x: [kek[2:-1] for kek in x])
# Out:
# CPU times: user 1min 39s, sys: 3.63 s, total: 1min 43s
# Wall time: 1min 46s

# %%
# %%time

df['gender_cat'] = df['gender'].map(dict_gender_to_gendercategory)
df['age_cat'] = df['age'].map(dict_age_to_agecategory)

df['time_list'] = df['user_json'].map(lambda x: [visit['timestamp'] for visit in x['visits']])

df['visits'] = df['time_list'].apply(len)
df['time_range'] = df['time_list'].apply(np.ptp)
df['visit_rate'] = df['time_range']/df['visits']

df['unique_domains_cnt'] = df['domain_list'].apply(lambda x: len(set(x)))
df['tot_domains_cnt'] = df['domain_list'].apply(lambda x: len(x))
df['avg_visits_per_domain'] = df['tot_domains_cnt']/df['unique_domains_cnt']
# Out:
# CPU times: user 2.89 s, sys: 364 ms, total: 3.25 s
# Wall time: 3.42 s

# %% [markdown]
# ## from json

# %% [markdown]
# #### read json

# %%
import json

# %%
# !pwd
# Out:
# /Users/antonina.goryacheva/Desktop/content_bigdata10_proj1_kek/notebooks

# %%
# %%time
with open('../data/titles-aiohttp.json', 'r') as f:
    results = json.load(f)
# Out:
# CPU times: user 1.56 s, sys: 230 ms, total: 1.79 s
# Wall time: 2.29 s

# %%
results
# Out:
# {'юрист-михаил-бабин.рф': {'domain': 'юрист-михаил-бабин.рф',
#   'url': 'http://юрист-михаил-бабин.рф',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host юрист-михаил-бабин.рф:80 ssl:None [nodename nor servname provided, or not known]'},
#  'эфирныемасла.рф': {'domain': 'эфирныемасла.рф',
#   'url': 'http://эфирныемасла.рф',
#   'title': 'Интернет магазин эфирных масел, аромакосметики и ароматерапии «ЦА Ирис».',
#   'keywords': None},
#  'эролюб.рф': {'domain': 'эролюб.рф',
#   'url': 'http://эролюб.рф',
#   'title': 'Эролюб.рф - страстные знакомства для взрослых с реальными фото. | Сайт для серьёзных отношений, любви и романтики для встреч и личной жизни.',
#   'keywords': None},
#  'шарикиоптом.рф': {'domain': 'шарикиоптом.рф',
#   'url': 'http://шарикиоптом.рф',
#   'title': 'Фитолампы, фитосветильники, прожекторы для растений, рассады, цветов. Системы освещения тепличных хозяйств. Лампы для гроубоксов, аквариумов. Низкие цены, курьерская доставка по всей стране.',
#   'keywords': None},
#  'чинамобил.рф': {'domain': 'чинамобил.рф',
#   'url': 'http://чинамобил.рф',
#   'title': 'Каталог запчастей CHERY GEELY LIFAN Brilliance Vortex',
#   'keywords': 'купить комплектующие для автомобилей чери джили лифан ховер тигго эмгранд бонус вортекс тинго'},
#  'чекиспб.рф': {'domain': 'чекиспб.рф',
#   'url': 'http://чекиспб.рф',
#   'title': 'Любые чеки СПб! - Главная',
#   'keywords': None},
#  'цветы-шуя.рф': {'domain': 'цветы-шуя.рф',
#   'url': 'http://цветы-шуя.рф',
#   'title': 'Каталог Ольги и Ирины Шуя.',
#   'keywords': 'Купить бегонии, пеларгонии, стрептокарпусы, комнатные растения, доставка почтой, курьером, самовывоз, пересылка, черенки растений почтой, заказать растения почтой.'},
#  'форум.хитник.рф': {'domain': 'форум.хитник.рф',
#   'url': 'http://форум.хитник.рф',
#   'title': 'Хита Урала. Клуб общения - Главная страница',
#   'keywords': None},
#  'уря.рф': {'domain': 'уря.рф',
#   'url': 'http://уря.рф',
#   'title': 'УРЯ.рф — люди, события, факты',
#   'keywords': None},
#  'урорамф.рф': {'domain': 'урорамф.рф',
#   'url': 'http://урорамф.рф',
#   'title': 'Толстое жирное порно',
#   'keywords': None},
#  'техцентр-урал.рф': {'domain': 'техцентр-урал.рф',
#   'url': 'http://техцентр-урал.рф',
#   'title': 'Акции, Запчасти Урал Екатеринбург, Запчасти к бульдозерам Т-170/130, Б-10',
#   'keywords': None},
#  'техно-мото.рф': {'domain': 'техно-мото.рф',
#   'url': 'http://техно-мото.рф',
#   'title': 'Продажа мототехники и запасных частей',
#   'keywords': None},
#  'спорт73.рф': {'domain': 'спорт73.рф',
#   'url': 'http://спорт73.рф',
#   'title': 'Спорт в Ульяновске |',
#   'keywords': None},
#  'спецбто.рф': {'domain': 'спецбто.рф',
#   'url': 'http://спецбто.рф',
#   'title': 'СпецБТО — Запчасти для спецтехники',
#   'keywords': None},
#  'софт-варез.рф': {'domain': 'софт-варез.рф',
#   'url': 'http://софт-варез.рф',
#   'title': 'Софт-Варез.РФ - Бесплатные программы',
#   'keywords': None},
#  'слонопотамия.рф': {'domain': 'слонопотамия.рф',
#   'url': 'http://слонопотамия.рф',
#   'title': 'Интернет-магазин игрушек, подарков и слонов - Слонопотамия.рф',
#   'keywords': None},
#  'секвойя.рф': {'domain': 'секвойя.рф',
#   'url': 'http://секвойя.рф',
#   'title': 'Форум юридической поддержки «Секвойя»',
#   'keywords': None},
#  'салон-пекинес.рф': {'domain': 'салон-пекинес.рф',
#   'url': 'http://салон-пекинес.рф',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host салон-пекинес.рф:80 ssl:None [nodename nor servname provided, or not known]'},
#  'решу.рф': {'domain': 'решу.рф',
#   'url': 'http://решу.рф',
#   'title': 'Решу.РФ - заказ решений на аукционе за минимальную цену с максимальным качеством',
#   'keywords': None},
#  'рецепты-вкусно.рф': {'domain': 'рецепты-вкусно.рф',
#   'url': 'http://рецепты-вкусно.рф',
#   'title': 'Вкусные рецепты | Готовим быстро и вкусно!',
#   'keywords': None},
#  'омвд-тосно.рф': {'domain': 'омвд-тосно.рф',
#   'url': 'http://омвд-тосно.рф',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host омвд-тосно.рф:80 ssl:None [nodename nor servname provided, or not known]'},
#  'нумизмания.рф': {'domain': 'нумизмания.рф',
#   'url': 'http://нумизмания.рф',
#   'title': 'Нумизмания - портал нумизматов - монеты россии, аукцион монет, магазин монет, каталоги монет',
#   'keywords': None},
#  'ножи-витязь.рф': {'domain': 'ножи-витязь.рф',
#   'url': 'http://ножи-витязь.рф',
#   'title': 'Ножи «Русский Витязь». Официальный интернет-магазин от производителя.',
#   'keywords': None},
#  'маркет.рф': {'domain': 'маркет.рф',
#   'url': 'http://маркет.рф',
#   'title': None,
#   'keywords': None,
#   'error': 'None'},
#  'малоэтажное-строительство-в.рф': {'domain': 'малоэтажное-строительство-в.рф',
#   'url': 'http://малоэтажное-строительство-в.рф',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host малоэтажное-строительство-в.рф:80 ssl:None [nodename nor servname provided, or not known]'},
#  'лекарственныетравы.net': {'domain': 'лекарственныетравы.net',
#   'url': 'http://лекарственныетравы.net',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host лекарственныетравы.net:80 ssl:None [nodename nor servname provided, or not known]'},
#  'клипарт.рф': {'domain': 'клипарт.рф',
#   'url': 'http://клипарт.рф',
#   'title': 'CLIPARTO | Фотографии большого размера, 3D иллюстрации и векторный клипарт',
#   'keywords': None},
#  'карта74.рф': {'domain': 'карта74.рф',
#   'url': 'http://карта74.рф',
#   'title': 'КАРТА74.рф - туристический портал Челябинской области',
#   'keywords': None},
#  'истра.рф': {'domain': 'истра.рф',
#   'url': 'http://истра.рф',
#   'title': 'Главная страница - Истра.рф',
#   'keywords': None},
#  'иваново-постель.рф': {'domain': 'иваново-постель.рф',
#   'url': 'http://иваново-постель.рф',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host иваново-постель.рф:80 ssl:None [nodename nor servname provided, or not known]'},
#  'за40.рф': {'domain': 'за40.рф',
#   'url': 'http://за40.рф',
#   'title': 'За40.рф - знакомства кому за 40. | Чат и общение для серьёзных отношений и любви после 40 лет.',
#   'keywords': None},
#  'городской-суд.рф': {'domain': 'городской-суд.рф',
#   'url': 'http://городской-суд.рф',
#   'title': 'ИНЮСТА | раздел имущества при разводе, развод через суд, расторжение брака без присутствия и без согласия  - услуги адвоката и юриста',
#   'keywords': None},
#  'воронеж.пятаяпередача.рф': {'domain': 'воронеж.пятаяпередача.рф',
#   'url': 'http://воронеж.пятаяпередача.рф',
#   'title': 'Интернет магазин автозапчастей для иномарок в Воронеже | Пятая передача',
#   'keywords': None},
#  'водолей.рф': {'domain': 'водолей.рф',
#   'url': 'http://водолей.рф',
#   'title': 'ВОДОЛЕЙ - интернет магазин сантехники официальный сайт в Красноярске в Красноярске | Водолей.рф',
#   'keywords': None},
#  'випе.рф': {'domain': 'випе.рф',
#   'url': 'http://випе.рф',
#   'title': 'Популярные товары - купить в Нижнем Новгороде - магазин одежды',
#   'keywords': None},
#  'велес30.рф': {'domain': 'велес30.рф',
#   'url': 'http://велес30.рф',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host велес30.рф:80 ssl:None [nodename nor servname provided, or not known]'},
#  'вамдам.рф': {'domain': 'вамдам.рф',
#   'url': 'http://вамдам.рф',
#   'title': 'ВамДам.рф - знакомства для взрослых и общение для любовных отношений | Сайт серьезных знакомств для близких отношений и поиска любовниц или любовников.',
#   'keywords': None},
#  'бревенчатыесрубы.рф': {'domain': 'бревенчатыесрубы.рф',
#   'url': 'http://бревенчатыесрубы.рф',
#   'title': 'Дома из оцилиндрованного бревна, бани из оцилиндрованного бревна, садовые домики из минибруса, гостевые домики, дом из минибруса в СПб, Санкт-Петербурге, Карелии. Компания «Экорон»',
#   'keywords': None},
#  'артемизия.рф': {'domain': 'артемизия.рф',
#   'url': 'http://артемизия.рф',
#   'title': 'Артемизия - натуральные сахарозаменители и продукты из стевии',
#   'keywords': None},
#  'авто-схема.рф': {'domain': 'авто-схема.рф',
#   'url': 'http://авто-схема.рф',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host авто-схема.рф:80 ssl:None [nodename nor servname provided, or not known]'},
#  'zzombi.ru': {'domain': 'zzombi.ru',
#   'url': 'http://zzombi.ru',
#   'title': 'Зомби игры. Играть в зомби онлайн бесплатно // zZombi.ru',
#   'keywords': 'зомби, игры зомби, против зомби, zombie, играть, игра, игры, онлайн, флеш, флэш, бесплатно',
#   'description': '☠ Игры зомби объединяют в себе популярные онлайн развлечения: стрелялки, гонки на машинах, растения против зомби и бродилки. Начните играть в зомби онлайн и уничтожьте как можно больше ходячих мертвецов всеми доступными методами.'},
#  'zzap.ru': {'domain': 'zzap.ru',
#   'url': 'http://zzap.ru',
#   'title': 'Запчасти для иномарок и грузовых авто. Поиск запчастей. Купить запчасти. Москва и область.',
#   'keywords': 'поиск запчастей, запчасти для иномарок, автозапчасти для иномарок, запчасти иномарки, поиск по VIN коду, каталог запчастей, онлайн каталог, запчасти в интернете, купить запчасти, найти и купить запчасти',
#   'description': 'Каталоги автозапчастей для иномарок. Поиск запчастей по VIN коду. Купить запчасти в магазинах. Москва и область.'},
#  'zz.te.ua': {'domain': 'zz.te.ua',
#   'url': 'http://zz.te.ua',
#   'title': 'Новини Тернополя і області – За Збручем | статті, прогнози, свіжі новини',
#   'keywords': None,
#   'description': None},
#  'zynka.se': {'domain': 'zynka.se',
#   'url': 'http://zynka.se',
#   'title': 'Zynka',
#   'keywords': None,
#   'description': None},
#  'zynga.com': {'domain': 'zynga.com',
#   'url': 'http://zynga.com',
#   'title': 'Free Mobile & Online Games - Zynga - Zynga',
#   'keywords': None,
#   'description': 'Online games & mobile games offer limitless fun! Play the most popular free games around by Zynga - Farmville, Hit it Rich, Zynga Poker and many more!'},
#  'zwinky.com': {'domain': 'zwinky.com',
#   'url': 'http://zwinky.com',
#   'title': 'Gaming Wonderland',
#   'keywords': None,
#   'description': None},
#  'zvukomaniya.ru': {'domain': 'zvukomaniya.ru',
#   'url': 'http://zvukomaniya.ru',
#   'title': None,
#   'keywords': None,
#   'description': None},
#  'zvukofrenia.ru': {'domain': 'zvukofrenia.ru',
#   'url': 'http://zvukofrenia.ru',
#   'title': 'В поисках неадекватной реальности - Системно-векторная психология',
#   'keywords': None,
#   'description': 'Системно-векторная психология'},
#  'zvukobook.ru': {'domain': 'zvukobook.ru',
#   'url': 'http://zvukobook.ru',
#   'title': 'Pharmio.ru  о лекарственных травах, сборах и расстениях',
#   'keywords': 'настои и травы, лекарственные растения, лечебные травы, все о травах, народная медицина, здоровье, болезни, лечение болезней, народная медицина, лекарственные растения',
#   'description': 'Сайт о лекарственных травах и расстениях'},
#  'zvuki-tut.narod.ru': {'domain': 'zvuki-tut.narod.ru',
#   'url': 'http://zvuki-tut.narod.ru',
#   'title': 'Звуки.',
#   'keywords': 'звуки',
#   'description': 'Скачать звуки.'},
#  'zvput.ru': {'domain': 'zvput.ru',
#   'url': 'http://zvput.ru',
#   'title': 'Поиск Туров — Туроператор Звёздный Путь - Туры и путевки по выгодным ценам онлайн, горящие туры',
#   'keywords': 'Туры на море, путевки в санатории, покупка авиабилетов, пляжный отдых, Отели Болгарии,  туры онлайн, оздоровительные туры, найти туры, путешествия по странам, отдых по направлениям, горящие туры',
#   'description': 'Туры на море – онлайн подбор и бронирование на курорты Турции, Египта, Болгарии. Путевки в санатории в Беларуси, Сочи, Крыма. Горящие туры.'},
#  'zvonki.octo.net': {'domain': 'zvonki.octo.net',
#   'url': 'http://zvonki.octo.net',
#   'title': 'Access Denied',
#   'keywords': None,
#   'description': None},
#  'zvoniperm.ru': {'domain': 'zvoniperm.ru',
#   'url': 'http://zvoniperm.ru',
#   'title': 'Интернет-магазин электроники в Перми - ZvoniPerm.ru +7(342)298-31-35',
#   'keywords': 'купить Apple Iphone \xa0в Перми,купить Iphone X в Перми,купить айфон 8 по самой низкой цене в Перми',
#   'description': 'Продажа телефонов Apple в Интернет-магазине ZvoniPerm.ru. У нас Вы можете купить новые Apple по самой низкой цене в Перми.'},
#  'zvonilki.net': {'domain': 'zvonilki.net',
#   'url': 'http://zvonilki.net',
#   'title': '—качать музыку на телефон бесплатно, рингтоны без регистрации, бесплатные мелодии на звонок',
#   'keywords': 'скачать музыку на телефон бесплатно, бесплатные рингтоны, скачать рингтоны бесплатно без регистрации, мелодии на звонок',
#   'description': '—качать музыку на телефон, рингтоны бесплатно, без регистрации'},
#  'zvezdi.ru': {'domain': 'zvezdi.ru',
#   'url': 'http://zvezdi.ru',
#   'title': 'Звёзды.ru',
#   'keywords': 'звёзды.ру, мода и стиль, фигура и диета, красота и пластика, романы и свадьбы, дом и дети, семейные проблемы, светская хроника, фотосессии звезд, бьюти видео, восходящие звезды, лайфхаки, музыкальные новинки, биографии знаменитостей',
#   'description': 'Онлайн-журнал о красоте, моде, стиле жизни и обо всём, что делает женщин настоящими звёздами.'},
#  'zvezdi.mirtesen.ru': {'domain': 'zvezdi.mirtesen.ru',
#   'url': 'http://zvezdi.mirtesen.ru',
#   'title': 'МирТесен - рекомендательная социальная сеть',
#   'keywords': None,
#   'description': 'MirTesen.ru — рекомендательная социальная сеть. Следите за самой интересной и актуальной информацией, найдите собеседников по любой важной для вас теме. Создайте свой сайт и соберите на нем множество читателей. Участвуйте в социальной сети и будьте всегда в курсе событий!'},
#  'zveryshki.ru': {'domain': 'zveryshki.ru',
#   'url': 'http://zveryshki.ru',
#   'title': None,
#   'keywords': None,
#   'error': 'Connection refused'},
#  'zveryatam.ru': {'domain': 'zveryatam.ru',
#   'url': 'http://zveryatam.ru',
#   'title': 'Интернет-магазин зоотоваров в Москве - зоомагазин ЗВЕРЯТАМ.РУ -  недорогие товары для домашних животных с доставкой',
#   'keywords': 'Интернет-магазин, купить, товары для животных, зоомагазин, корм',
#   'description': ''},
#  'zveroboy.ru': {'domain': 'zveroboy.ru',
#   'url': 'http://zveroboy.ru',
#   'title': 'ЗВЕРОБОЙ.ру :: Главная',
#   'keywords': 'зверобой, zveroboy, охотничье,оружие,нарезной карабин, ружье, прицел, оптический прицел, купить оружие, боеприпасы, патроны, нарезные патроны, карабин со сменными стволами, hensoldt, march, titan, sako, barrett, accuracy, кристенсен армс, christensen arms, титан, австрийский карабин титан, снайперская винтовка, высокоточная винтовка, спортивное оружие, снайпинг, карбоновый карабин, карбон, сабатти, sabatti, в москве, патроны норма, norma, лапуа, сценар, хорнади, холланд и холланд, holland&holland, сменные стволы, комбинированное ружье, зауер, sauer, рикнагель, рекнагель, recknagel, варминт, варминтинг, мишень, точно в цель, скм, rws, 30-06 sprg, 300 win.mag, 243 win, 338 lapua mag, ,',
#   'description': None},
#  'zveridikie.ru': {'domain': 'zveridikie.ru',
#   'url': 'http://zveridikie.ru',
#   'title': 'Дикие звери и домашние животные, их роль в жизни человека',
#   'keywords': None,
#   'description': None},
#  'zvenigovo.all.biz': {'domain': 'zvenigovo.all.biz',
#   'url': 'http://zvenigovo.all.biz',
#   'title': 'Бизнес портал России - Торгуй по новому на https://ru.all.biz',
#   'keywords': None,
#   'description': 'AllBiz Россия - Бизнес портал России: товары, услуги, компании, поставщики, объявления, классификатор товаров. Торгуй по новому на https://ru.all.biz! Бесплатная регистрация.'},
#  'zva.zp.ua': {'domain': 'zva.zp.ua',
#   'url': 'http://zva.zp.ua',
#   'title': 'Запорожский Завод Высоковольтной Аппаратуры - производство электротехнического оборудования',
#   'keywords': 'ззва, завод высоковольтной аппаратуры, измерительные трансформаторы, \n    трансформаторы напряжения, трансформаторы тока, купить трансформатор, масляные \n    трансформаторы, элегазовые трансформаторы',
#   'description': 'Изготовление и продажа трансформаторов тока, напряжения, КРУ, \n    элегазовых трансформаторов,встроенных трансформаторов, выкатных элементов'},
#  'zut-zakaz.ru': {'domain': 'zut-zakaz.ru',
#   'url': 'http://zut-zakaz.ru',
#   'title': 'zut-zakaz.ru',
#   'keywords': None,
#   'description': None},
#  'zup1c.ru': {'domain': 'zup1c.ru',
#   'url': 'http://zup1c.ru',
#   'title': 'Кадровый учет и расчет зарплаты в 1С 8.3 ЗУП 3.1. 1С Зарплата и Управление Персоналом.',
#   'keywords': '1с 8.3 зуп 3.1, расчет зарплаты 1с зуп 3.1, 6-ндфл зуп 8.3, расчет по страховым взносам 1с зуп',
#   'description': 'Блог Герасимова Дмитрия по ведению учет в 1С 8.3 ЗУП 3.1 в статьях и уроках: кадровый учет, учет зарплаты, отчетность, администрирование 1С'},
#  'zumagames.ru': {'domain': 'zumagames.ru',
#   'url': 'http://zumagames.ru',
#   'title': 'ИГРЫ ZUMA, играть в игры ZUMA онлайн бесплатно',
#   'keywords': None,
#   'description': 'ИГРЫ ZUMA, играть в игры ZUMA онлайн бесплатно'},
#  'zumadeluxe.ru': {'domain': 'zumadeluxe.ru',
#   'url': 'http://zumadeluxe.ru',
#   'title': 'Игра Zuma Deluxe, играть в версии Зума онлайн',
#   'keywords': 'зума, zuma, deluxe, игра, играть, онлайн, online, флеш, бесплатно',
#   'description': 'Онлайн игры по типу Zuma Deluxe на любой вкус: с цветными шарами, пиратскими пушками, драгоценными камнями и фруктами. Здесь можно играть в Зуму и многое другое!'},
#  'zuks.ru': {'domain': 'zuks.ru',
#   'url': 'http://zuks.ru',
#   'title': 'Западное управление жилищно-коммунальными системами',
#   'keywords': None,
#   'description': ''},
#  'zubzone.ru': {'domain': 'zubzone.ru',
#   'url': 'http://zubzone.ru',
#   'title': 'Лечение зубов',
#   'keywords': None,
#   'description': None},
#  'zubr.com': {'domain': 'zubr.com',
#   'url': 'http://zubr.com',
#   'title': 'ZUBR - каталог белорусских интернет-ресурсов',
#   'keywords': None,
#   'description': None},
#  'zubovskaya-banya.ru': {'domain': 'zubovskaya-banya.ru',
#   'url': 'http://zubovskaya-banya.ru',
#   'title': 'Истёк срок регистрации домена\xa0zubovskaya-banya.ru',
#   'keywords': None},
#  'zubo-chistka.ru': {'domain': 'zubo-chistka.ru',
#   'url': 'http://zubo-chistka.ru',
#   'title': [],
#   'keywords': None,
#   'description': 'width=device-width, initial-scale=1'},
#  'zubnaya-apteka.ru': {'domain': 'zubnaya-apteka.ru',
#   'url': 'http://zubnaya-apteka.ru',
#   'title': 'Продажа средств гигиены полости рта, стоматологического оборудования',
#   'keywords': 'Главная',
#   'description': None},
#  'zubbo.ru': {'domain': 'zubbo.ru',
#   'url': 'http://zubbo.ru',
#   'title': 'Стоматологии в Москва - детские стоматологии, бесплатные стоматологии, стоматологии метро, цены стоматологий - Zubbo.ru',
#   'keywords': '',
#   'description': 'Стоматологии в Москва - детские стоматологии, бесплатные стоматологии, стоматологии метро. Отзывы о стоматологиях Москва, рейтинг стоматологий Москва, стоматологии на карте Москва.'},
#  'zte.ru': {'domain': 'zte.ru',
#   'url': 'http://zte.ru',
#   'title': 'Корпорация ZTE',
#   'keywords': None,
#   'description': None},
#  'zt-news.org.ua': {'domain': 'zt-news.org.ua',
#   'url': 'http://zt-news.org.ua',
#   'title': 'Новини Житомира  |  Новости Житомира',
#   'keywords': 'новини, політика, житомир, влада, мер, Новини Житомира, Житомир, новости Житомира, Житомирська Міська рада, сайт новин, інфо Житомир',
#   'description': 'Новини Житомира. Новости Житомира. Житомир. Транспорт Житомира. Останні новини Житомир. Последние новости Житомир.'},
#  'zsgk-tmn.ru': {'domain': 'zsgk-tmn.ru',
#   'url': 'http://zsgk-tmn.ru',
#   'title': 'Сайт Западно-Сибирского государственного колледжа города Тюмени',
#   'keywords': 'факультеты, специальность, преподаватели',
#   'description': 'Западно-Сибирский государственный колледж является государственным автономным профессиональным образовательным учреждением Тюменской области, которое осуществляет реализацию профессиональных образовательных программ среднего профессионального образования.'},
#  'zserials.tv': {'domain': 'zserials.tv',
#   'url': 'http://zserials.tv',
#   'title': '«Мир Сериалов» — Все Сериалы мира смотреть онлайн, скачать торрент бесплатно.',
#   'keywords': 'Сериалы онлайн, Сериалы торрент, Скачать сериалы, Сериалы бесплатно, смотреть сериалы, лучшие сериалы, все сериалы онлайн, все сериалы торрент, Аниме онлайн, Аниме торрент, Мультсериалы онлайн, Мультсериалы торрент, Документальные сериалы онлайн торрент',
#   'description': 'Смотрите онлайн или качайте через торрент все зарубежные и русские сериалы мира, мультсериалы, аниме, документальные сериалы и телепередачи. Все сериалы абсолютно бесплатные.'},
#  'zserials.ru': {'domain': 'zserials.ru',
#   'url': 'http://zserials.ru',
#   'title': 'zSerials.ru — Новые серии сериалов - по сезонам - онлайн',
#   'keywords': None,
#   'description': 'zSerials.ru — Новые серии сериалов - по сезонам - онлайн'},
#  'zsccs.ru': {'domain': 'zsccs.ru',
#   'url': 'http://zsccs.ru',
#   'title': 'ЗСЦЦС | Западно-Сибирский Центр ценообразования в строительстве',
#   'keywords': 'Гранд-Смета в Новосибирске, Гранд-СтройИнфо, Стройформ, сметы, сметное дело, сметный аутсорсинг, сметный консалтинг, Гранд-Смета 6.0, заказать Гранд-Смету, купить Гранд-Смету, обновление Гранд-Сметы, заказать смету, дилер Гранд-Сметы',
#   'description': 'Продажа и сопровождение программных комплексов Гранд-Смета, Гранд-СтройИнфо, Стройформ, нормативных баз. Составление проектно-сметной документации. Консалтинг.'},
#  'zr.ru': {'domain': 'zr.ru',
#   'url': 'http://zr.ru',
#   'title': 'Сайт За\xa0рулем www.zr.ru\xa0— Статьи, новости, тесты, обзоры, обсуждения на\xa0форуме, фото, видео',
#   'keywords': None,
#   'description': 'Официальный сайт журнала «За рулем». Ежедневные автомобильные новости и статьи, тесты, характеристики и подбор машин. С Pajero я перестал быть домоседом - честный рассказ автовладельца - сайт «За рулем»'},
#  'zplitka.narod.ru': {'domain': 'zplitka.narod.ru',
#   'url': 'http://zplitka.narod.ru',
#   'title': 'Зеркальное панно, зеркальная плитка, мозаика зеркальная в Минске',
#   'keywords': 'Купить Зеркальную плитка с фацетом, купить зеркальное панно ромбом, купить зеркальную плитку ромбом, купить зеркальную плитку шестигранником (сота), купить зеркальное панно Минск, зеркальные ромбы, зеркальная плитка купить, зеркальная плитка с фацетом, зеркальная плитка цена, зеркальная плитка с фацетом купить, зеркальная плитка на стену, зеркальная плитка с фацетом фото, зеркальная плитка в ванной, Фартук для Кухни Минск, плитка зеркальная католог,  зеркальная плитка с фацетом купить, зеркальная плитка +в интерьере, зеркальная плитка фото, фартук зеркальная плитка, зеркальная плитка +в ванной, зеркальная плитка +на стену, зеркальная плитка цена, зеркальная плитка +в интерьере фото, клей +для зеркальной плитки,  +чем затереть зеркальную мозаику, зеркальный плитка, зеркальный интерьер, купить зеркальную плитку в минске, зеркальная плитка минск, зеркальная плитка в коридоре, зеркальная плитка производитель',
#   'description': 'Высококачественная зеркальная плитка / панно по низким ценам'},
#  'zovshop.ru': {'domain': 'zovshop.ru',
#   'url': 'http://zovshop.ru',
#   'title': 'Кухни ЗОВ в Москве — белорусские кухни на заказ от производителя. Кухонная мебель ЗОВ и аксессуары для кухонь',
#   'keywords': 'кухни ЗОВ, белорусские кухни, кухни на заказ, кухни в Москве',
#   'description': 'Официальный сайт представителя белорусской мебельной фабрики ЗОВ. Фирменный салон кухонь ЗОВ в Москве.'},
#  'zorkagold.by': {'domain': 'zorkagold.by',
#   'url': 'http://zorkagold.by',
#   'title': None,
#   'keywords': None,
#   'error': 'None'},
#  'zopo-mobile.ru': {'domain': 'zopo-mobile.ru',
#   'url': 'http://zopo-mobile.ru',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host zopo-mobile.ru:80 ssl:None [nodename nor servname provided, or not known]'},
#  'zoovet.kh.ua': {'domain': 'zoovet.kh.ua',
#   'url': 'http://zoovet.kh.ua',
#   'title': 'Ветеринарная клиника Мадагаскар - все виды ветеринарных услуг на Оболони, Киев',
#   'keywords': 'ветеринарная клиника, ветеринарная клиника Киев, ветеринарная клиника Оболонь, ветклиника Киев',
#   'description': 'Ветеринарная клиника в Киеве, на Оболони предоставляет полный спектр ветеринарных услуг: лечебно-диагностические исследования, вакцинация, лабораторные исследования, хирургия, гостиница для животных'},
#  'zoovet.info': {'domain': 'zoovet.info',
#   'url': 'http://zoovet.info',
#   'title': 'Ветеринария, новости ветеринарии, болезни животных',
#   'keywords': 'ветеринария новости статьи болезни животных содержание собак кошек лошадей студент-ветеринар',
#   'description': 'Справочник для ветеринарных врачей и владельцев животных.'},
#  'zootubex.us': {'domain': 'zootubex.us',
#   'url': 'http://zootubex.us',
#   'title': 'ZootubeX',
#   'keywords': 'zootubex,sexo,sex,dog,horse,caballos,perros,animal xxx,free cum animal,free animalporn,zoo tube xxx,zoo vids tubex,follar con animales,sexo con mascotas',
#   'description': 'sexo con animales,zoofilia gratis,videos de mascotas,sex zooskool,porno con animales,scenes of zoophilia,videos gratis zoofilia'},
#  'zoospravka.ru': {'domain': 'zoospravka.ru',
#   'url': 'http://zoospravka.ru',
#   'title': 'ЗооСправка - справочник по зоотоварам, предприятиям зообизнеса и домашним животным',
#   'keywords': 'аквариум, аквариумистика, ветеринарные препараты, ветпрепараты, витамины, грызуны, домашние животные, зообизнес, зоотовар, канарейка, консервы, корм, кошка, кролик, крыса, лакомство, лекарство, мышь, оборудование, обувь, одежда, попугай, птица, растение, рыба, собака, ссылки, террариум, террариумистика, товары, хомяк, цены',
#   'description': 'ЗооСправка - каталоги питомников домашних животных и предприятий зообизнеса. Кошки, собаки, птицы, грызуны, рептилии, амфибии, насекомые и рыбки - фото, описания пород и видов. Выбрать и купить зоотовары для домашних животных, аквариума, террариума.'},
#  'zooshop.golianovo.info': {'domain': 'zooshop.golianovo.info',
#   'url': 'http://zooshop.golianovo.info',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host zooshop.golianovo.info:80 ssl:None [nodename nor servname provided, or not known]'},
#  'zoon.ru': {'domain': 'zoon.ru',
#   'url': 'http://zoon.ru',
#   'title': 'Zoon.ru - удобный выбор ресторанов, медицинских центров, спа-салонов, фитнес клубов и других услуг в Москве',
#   'keywords': 'zoon, услуги Москвы, справочник Москвы, скидки Москвы',
#   'description': 'Выбор лучших услуг в Москве: рестораны, салоны красоты, медицина и многое другое на Zoon.ru. Фотографии, отзывы, акции, скидки, фильтры для поиска.'},
#  'zoomgirls.net': {'domain': 'zoomgirls.net',
#   'url': 'http://zoomgirls.net',
#   'title': 'Zoomgirls nude wallpapers, sexy exposed girls and naked celebrities images',
#   'keywords': 'zoomgirls sexy wallpapers, nude girls, porn stars, naked babes, celebrities, pornstars, tattoo beauty, xxx models, babes and cars, girls and bikes, seductive, mature, arousing, sensual, inked nudes, skin, exposed, thong, images, free',
#   'description': 'ZoomGirls nude wallpapers is the place to get the best looking models, naked porn stars and exposed sexy girls hd and wide resolution porn images free'},
#  'zoomby.ru': {'domain': 'zoomby.ru',
#   'url': 'http://zoomby.ru',
#   'title': 'Онлайн-телевидение Zoomby.ru – бесплатный видео сервис | Смотреть фильмы онлайн бесплатно без регистрации и смс на Zoomby.ru',
#   'keywords': None,
#   'description': 'Приветствуем Вас в Онлайн-телевидение Zoomby.ru и предлагаем посмотреть наше видео. Все видео на Zoomby.ru бесплатно и в хорошем качестве.'},
#  'zoomarket.zooexpress-spb.ru': {'domain': 'zoomarket.zooexpress-spb.ru',
#   'url': 'http://zoomarket.zooexpress-spb.ru',
#   'title': 'Интернет-магазин зоотоваров, купить товары для животных, доставка в Санкт-Петербурге - Zoomarket Zooexpress',
#   'keywords': 'зоотовары,\r\nинтернет магазин зоотовары,\r\nинтернет магазин товаров для жиовтных,\r\nкупить товары для животных,\r\nдоставка зоотоваров',
#   'description': 'Купите зоотовары в интернет-магазине Зооэкспресс. У нас широкий выбор товаров собак, кошек, грызунов, хорьков, птиц, рыб и рептилий. Доставка зоотоваров для животных по Санкт-Петербургу и Ленобласти. Оформляйте заказ!'},
#  'zoomagazin.kz': {'domain': 'zoomagazin.kz',
#   'url': 'http://zoomagazin.kz',
#   'title': 'Интернет-Зоомагазин - Чемпион, зоотовары и корма для Ваших питомцев по самым лучшим ценам. Стрижки собак и кошек в Алматы, подготовка к выставкам, груминг-салон, выставочный груминг собак и кошек всех пород.',
#   'keywords': 'зоомаркет, интернет-магазин, бесплатная, доставка, корм, купить, алматы, онлайн, зоомагазин, зоотовары, fcana, royal canin, pro plan, зоопарикмахерская, стрижка собак +кошек, frontline, груминг, миска, зоосалон, чемпион, зоо кз, выставка собак, наполн',
#   'description': 'Сеть зоомагазинов зоотоваров и кормов для собак и кошек по низким ценам. Бесплатная доставка по г. Алматы. Зоопарикмахерские и груминг салоны.'},
#  'zookuznetsk.forum24.ru': {'domain': 'zookuznetsk.forum24.ru',
#   'url': 'http://zookuznetsk.forum24.ru',
#   'title': 'Зоо-Кузнецк',
#   'keywords': None,
#   'description': None},
#  'zoohoz.ru': {'domain': 'zoohoz.ru',
#   'url': 'http://zoohoz.ru',
#   'title': 'Zoohoz.ru - животноводство (хозяйство) своими руками',
#   'keywords': None,
#   'description': 'На сайте zoohoz мы рассмотрим фермерское хозяйство от А до Я. Наш сайт планируется как передовой портал по животноводств'},
#  'zoohall.com.ua': {'domain': 'zoohall.com.ua',
#   'url': 'http://zoohall.com.ua',
#   'title': 'ј\xa0¬ј–»”ћџ » ¬ќƒќѕјƒџ - [zoohall.com.ua]',
#   'keywords': 'стекл€нные перегородки, кухонные фартуки из стекла, офисные перегородки в алюминиевом профиле, входные группы из стекла, цельностекл€нные конструкции, витрины из стекла, двери внутренние из стекла, раздвижные системы дл€ дверей из стекла, душевые кабины из стекла, козырьки из стекла, лестницы со ступен€ми из стекла, ограждени€ из стекла',
#   'description': 'ZOOHALL.COM.UA - ј\xa0¬ј–»”ћџ | ¬ќƒќѕјƒџ | ѕ”«џ–№\xa0ќ¬џ≈ ѕјЌ≈Ћ» | —”’»≈ ј\xa0¬ј–»”ћџ | “≈––ј–»”ћџ | ¬ќЋ№≈–џ ...'},
#  'zoofilianet.com': {'domain': 'zoofilianet.com',
#   'url': 'http://zoofilianet.com',
#   'title': 'Videos Zoofilia - ZoofiliaNet',
#   'keywords': 'Peliculas de zoofilia, bestiality movies, beast videos, mujeres penetradas por animales, dog sex porn',
#   'description': 'Zoophilia site where can find all about zoo content, beast videos and zoofilia pictures. All bestiality lover find place to enjoy a feeling a way of life'},
#  'zoofilia.eu': {'domain': 'zoofilia.eu',
#   'url': 'http://zoofilia.eu',
#   'title': 'zoofilia.eu',
#   'keywords': None,
#   'description': None},
#  'zooexpress-spb.ru': {'domain': 'zooexpress-spb.ru',
#   'url': 'http://zooexpress-spb.ru',
#   'title': 'Зооэкспресс: зоотовары - зоомаркет, зооэкспресс, зоотовары спб, ветеринарная клиника круглосуточно, зоотовары оптом, опт в регионы, zooexpress',
#   'keywords': 'Зооэкспресс: зоотовары - зоомаркет, ветеринарная клиника круглосуточно, опт в регионы (zooexpress)',
#   'description': 'Зооэкспресс: зоотовары - зоомаркет, ветеринарная клиника круглосуточно, опт в регионы (zooexpress)'},
#  'zooeco.com': {'domain': 'zooeco.com',
#   'url': 'http://zooeco.com',
#   'title': 'Природа Планеты Земля. Фауна, флора, человек. МИР ЖИВОТНЫХ Евстафьева Игоря Леонидовича, Природа Земли,\r\n        Развитие жизни, динозавры, древний человек, Растения, Животные в доме, Кошки, Собаки, Птицы, Загадки планеты\r\n        ЗЕМЛЯ, Природа',
#   'keywords': 'Природа Планеты Земля. Фауна, флора, человек. Природа Земли, Развитие жизни, динозавры, древний человек, Растения, Животные в доме, Кошки, Собаки, Птицы, Загадки планеты ЗЕМЛЯ, Природа',
#   'description': 'Природа Планеты Земля. Фауна, флора, человек. Природа Земли, Развитие жизни, динозавры, древний человек, Растения, Животные в доме, Кошки, Собаки, Птицы, Загадки планеты ЗЕМЛЯ, ПриродаГлавная сайта МИР ЖИВОТНЫХ Евстафьева Игоря Леонидовича - на Мир Животных'},
#  'zooclub.ru': {'domain': 'zooclub.ru',
#   'url': 'http://zooclub.ru',
#   'title': 'Сайт о животных Зооклуб, портал про домашних и диких животных',
#   'keywords': None,
#   'description': None},
#  'zoobrilka.com': {'domain': 'zoobrilka.com',
#   'url': 'http://zoobrilka.com',
#   'title': '',
#   'keywords': None,
#   'description': None},
#  'zoo.taboo.cc': {'domain': 'zoo.taboo.cc',
#   'url': 'http://zoo.taboo.cc',
#   'title': '404 Not Found',
#   'keywords': None},
#  'zoo-secret.ru': {'domain': 'zoo-secret.ru',
#   'url': 'http://zoo-secret.ru',
#   'title': 'Интернет-магазин товаров для животных',
#   'keywords': None,
#   'description': None},
#  'zonwar.ru': {'domain': 'zonwar.ru',
#   'url': 'http://zonwar.ru',
#   'title': 'Большая военная энциклопедия',
#   'keywords': 'Оружие, боевая техника, пистолеты, автоматы, большая военная энциклопедия, холодное оружие, огнестрельное оружие, вооружение, армия, война',
#   'description': 'Большая военная энциклопедия, все об оружие, боевой технике, вооружении, армиях и войнах.'},
#  'zoneofgames.ru': {'domain': 'zoneofgames.ru',
#   'url': 'http://zoneofgames.ru',
#   'title': 'Zone of Games',
#   'keywords': None,
#   'description': None},
#  'zonakz.net': {'domain': 'zonakz.net',
#   'url': 'http://zonakz.net',
#   'title': None,
#   'keywords': None,
#   'error': 'None'},
#  'zombiday.ru': {'domain': 'zombiday.ru',
#   'url': 'http://zombiday.ru',
#   'title': 'Sex dating in clam lake wisconsin',
#   'keywords': None,
#   'description': 'I felt this site is very serious as soon as I created my'},
#  'zombicity.info': {'domain': 'zombicity.info',
#   'url': 'http://zombicity.info',
#   'title': 'Игра Зомби Ферма • Зомби Мания',
#   'keywords': None,
#   'description': 'Секреты игры Зомби Ферма, Зомби Мания Вконтакте, Одноклассники, Мэйл.ру, Фэйсбук. Сайт Зомби Фермы. Новости и обновления игры. Прохождение Зомби Фермы, Зомби Мании, советы. Картинки, фото и видео игры Зомби Ферма Мания на сайте ZombiCity.info'},
#  'zombia.ru': {'domain': 'zombia.ru',
#   'url': 'http://zombia.ru',
#   'title': 'Дешевые авиабилеты онлайн, цены. Поиск билетов на самолет и сравнение цен —  Aviasales.ru',
#   'keywords': 'дешевые авиабилеты онлайн, билеты на самолет дешево, спецпредложения авиакомпаний, цены на авиабилеты',
#   'description': 'Aviasales.ru помогает найти и купить самые дешевые авиабилеты. Поиск билетов на самолет по 728 авиакомпаниям, ведущим авиакассам и лучшие цены на авиабилеты.'},
#  'zomba.me': {'domain': 'zomba.me',
#   'url': 'http://zomba.me',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host zomba.me:80 ssl:None [nodename nor servname provided, or not known]'},
#  'zolotoyvek.ua': {'domain': 'zolotoyvek.ua',
#   'url': 'http://zolotoyvek.ua',
#   'title': 'Интернет магазин "Золотой Век"- золото, ювелирные изделия - сеть ювелирных магазинов, каталог ювелирных изделий.',
#   'keywords': 'Золото, ювелирные изделия, свадебное кольцо, браслет, подвес, серьги',
#   'description': 'Интернет магазин "Золотой Век"- золото, ювелирные изделия - сеть ювелирных магазинов, каталог ювелирных изделий.'},
#  'zolotoyvek.com': {'domain': 'zolotoyvek.com',
#   'url': 'http://zolotoyvek.com',
#   'title': 'zolotoyvek.com - Deleted | Undeveloped',
#   'keywords': None,
#   'description': 'The domain name zolotoyvek.com has been deleted. Discover millions of domains available for sale. Undeveloped keeps you safe.'},
#  'zolotoypesok-gel.ru': {'domain': 'zolotoypesok-gel.ru',
#   'url': 'http://zolotoypesok-gel.ru',
#   'title': 'Центр кузовного ремонта автомобилей - станция кузовного ремонта РемЕвроСервис',
#   'keywords': 'РемЕвроСервис, кузовные работы, слесарные работы, ремонт кузова',
#   'description': 'Центр кузовного ремонта РемЕвроСервис оперативно и качественно предоставляет комплекс современных услуг по обслуживанию легковых автомобилей различных марок.'},
#  'zolotosochi.com': {'domain': 'zolotosochi.com',
#   'url': 'http://zolotosochi.com',
#   'title': 'Сочи | Золото Сочи - городской портал',
#   'keywords': 'Сочи, городской портал сочи, портал сочи, сайт сочи, Золото Сочи',
#   'description': 'Сочи начинается с портала Золото Сочи - сайта, предоставляющего ценную и актуальную информацию о жизни города: афиша, новости, погода, работа и другие сервисы.'},
#  'zolotoe-koltso-tur.ru': {'domain': 'zolotoe-koltso-tur.ru',
#   'url': 'http://zolotoe-koltso-tur.ru',
#   'title': 'Туры по Золотому кольцу России : экскурсии по Золотому кольцу : тур Золотое кольцо : туры по России',
#   'keywords': None,
#   'description': 'Туры по Золотому Кольцу'},
#  'zoloterra.ru': {'domain': 'zoloterra.ru',
#   'url': 'http://zoloterra.ru',
#   'title': 'Курсы английского языка в Челябинске | Английский язык с носителем',
#   'keywords': 'курсы английского языка, курсы английского в челябинске, английский в челябинске',
#   'description': 'Курсы английского для взрослых и детей в Zoloterra. Преподаём английский язык в Челябинске с 2008 года. Обучение с носителями языка по выгодным ценам.'},
#  'zokl.ru': {'domain': 'zokl.ru',
#   'url': 'http://zokl.ru',
#   'title': 'Завод металлоконструкций и быстровозводимых зданий, сэндвич панелей и окон ПВХ в Минске',
#   'keywords': 'пластиковые окна пвх Минск производитель изготовитель',
#   'description': 'Завод занимается возведением быстровозводимых зданий, строительством ферм, производством металлоконструкций и сэндвич панелей. Огромный опыт работы и множество построенных объектов.'},
#  'zoegames.net': {'domain': 'zoegames.net',
#   'url': 'http://zoegames.net',
#   'title': 'Zoe Игры - Игры для девочек - Zoe Игры',
#   'keywords': 'Игры для девочек, Zoe Игры, Zoe куклой, Бесплатные онлайн игры для девочек',
#   'description': 'Бесплатные онлайн игры для девочек и Zoe куклой на zoegames.net'},
#  'zodchiy72.ru': {'domain': 'zodchiy72.ru',
#   'url': 'http://zodchiy72.ru',
#   'title': 'Зодчий',
#   'keywords': 'Бассейн, Зодчий, СК, Тюмень, ТюмГАСУ',
#   'description': None},
#  'zobbogames.com': {'domain': 'zobbogames.com',
#   'url': 'http://zobbogames.com',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host zobbogames.com:80 ssl:None [nodename nor servname provided, or not known]'},
#  'znayuvse.ru': {'domain': 'znayuvse.ru',
#   'url': 'http://znayuvse.ru',
#   'title': 'Знаю все! |',
#   'keywords': None,
#   'description': None},
#  'znayka.net': {'domain': 'znayka.net',
#   'url': 'http://znayka.net',
#   'title': 'Знайка.Net - Ваш помощник',
#   'keywords': 'сказки,советские мультфильмы,рассказы,дети,детский сайт,детские сказки,стихи,загадки,скороговорки,знайка,детские игры',
#   'description': 'Знайка - прекрасный мир, где вас ждут Сказки, Советские мультфильмы и Раскраски, Пословицы и Потешки, Стихи и Рассказы, Детские Игры и Песенки'},
#  'znay.ru': {'domain': 'znay.ru',
#   'url': 'http://znay.ru',
#   'title': 'ЗНАЙ СТРАХОВАНИЕ! - информационно-просветительский проект Андрея Знаменского - Знай страхование! | Страховой информационно-просветительский проект Андрея Знаменского: ключевые проблемы страхования, перспективы развития видов страхования и страхового рынка, материалы для страхователей, студентов и профессионалов.  | страхование, страховка, страховой полис, страховой случай, страхователь, страховщик,страхование,страховка,страховая компания,страховых компаний,страховщик,ЗНАЙ СТРАХОВАНИЕ! - информационно-просветительский проект Андрея Знаменского,Знай страхование!,Знай страхование!',
#   'keywords': None,
#   'description': None},
#  'znaniya-sila.narod.ru': {'domain': 'znaniya-sila.narod.ru',
#   'url': 'http://znaniya-sila.narod.ru',
#   'title': 'Знания-сила.народ.ру',
#   'keywords': 'Знания-сила, Astronomy, Physics, sciences, scientists, наука, научных, открытий, достижений, учёных, астрономов, физика, Эйнштейн, сайта, самая',
#   'description': 'Знания-сила.народ.ру'},
#  'znanija.com': {'domain': 'znanija.com',
#   'url': 'http://znanija.com',
#   'title': 'Школьные Знания.com - Решаем домашнее задание вместе',
#   'keywords': None,
#   'description': 'default'},
#  'znania.ru': {'domain': 'znania.ru',
#   'url': 'http://znania.ru',
#   'title': 'ЗНАНИЯ.РУ. Информация об учебных заведениях: вузах Москвы, институтах Москвы, школах, колледжах, курсах, детских садах.',
#   'keywords': None,
#   'description': None},
#  'znamenitosti.info': {'domain': 'znamenitosti.info',
#   'url': 'http://znamenitosti.info',
#   'title': 'Знаменитости.инфо | Новости шоу-бизнеса, светская хроника, знаменитости',
#   'keywords': 'Здесь ваши ключевые слова',
#   'description': 'Знаменитости.инфо - Новости шоу-бизнеса, светская хроника, знаменитости'},
#  'znakomstvo.besplatnoe.net': {'domain': 'znakomstvo.besplatnoe.net',
#   'url': 'http://znakomstvo.besplatnoe.net',
#   'title': 'Hessen, Frankfurt am Main — Suchresultate — Знакомство Табор — международный сайт знакомств, бесплатные знакомства Tabor — красивые девушки и парни — TОП-100',
#   'keywords': None,
#   'description': None},
#  'znakomstvas.znakomstvas2014.com': {'domain': 'znakomstvas.znakomstvas2014.com',
#   'url': 'http://znakomstvas.znakomstvas2014.com',
#   'title': [],
#   'keywords': None,
#   'description': 'See related links to what you are looking for.'},
#  'znakomstvamoscow.ru': {'domain': 'znakomstvamoscow.ru',
#   'url': 'http://znakomstvamoscow.ru',
#   'title': 'Знакомства в Москве. Бесплатный сайт знакомств для серьезных отношений в Москве и области',
#   'keywords': 'Знакомства в Москве,сайт знакомств для серьезных отношений Москва, бесплатный сайт знакомств Москва, знакомства без регистрации',
#   'description': 'Сайт знакомств ZnakomstvaMoscow.ru это анкеты девушек и парней со всего света. Регистрируйтесь и начинайте знакомиться и получать удовольствие от общения! Для пользователей социальных сетей: speed dating знакомства без регистрации.'},
#  'znakomstva.udmurtinfo.ru': {'domain': 'znakomstva.udmurtinfo.ru',
#   'url': 'http://znakomstva.udmurtinfo.ru',
#   'title': 'Знакомства LovePlanet.ru – сайт бесплатного онлайн общения с реальными людьми со всего мира!!',
#   'keywords': None,
#   'description': 'LovePlanet – БЕСПЛАТНЫЙ сайт знакомств с самой большой базой РЕАЛЬНЫХ анкет в Вашем городе и по всему миру. Знакомьтесь, общайтесь,  флиртуйте, найдите свою вторую половинку!'},
#  'znakomstva.poisk.su': {'domain': 'znakomstva.poisk.su',
#   'url': 'http://znakomstva.poisk.su',
#   'title': 'Знакомства | Поиск.su',
#   'keywords': 'знакомства.com, сайт знакомств, знакомство, чат знакомств, бесплатные знакомства, служба знакомств, клуб знакомств, знакомства с девушками, знакомства с мужчинами, общение, знакомства и общение, znakomstva, znakomstvo, интернет знакомства, путешествия',
#   'description': 'Знакомства.com –  бесплатный сайт для знакомств в Вашем городе и по всей России. Знакомьтесь с интересными людьми, общайтесь, пушешествуйте, играйте, флиртуйте.'},
#  'znakomstva.nu': {'domain': 'znakomstva.nu',
#   'url': 'http://znakomstva.nu',
#   'title': 'Знакомства для отношений серьезных и без обязательств на Znakomstva.Nu',
#   'keywords': 'сайт знакомств, знакомства, для серьезных отношений, без обязательств, на одну ночь, без регистрации',
#   'description': 'Самый большой 💘 сайт знакомств 💋 для поиска серьезных отношений и встреч на одну ночь без обязательств. Более 42 миллионов реальных анкет девушек, парней, женщин и мужчин с фотографиями. Удобный поиск второй половинки, можно легко и быстро познакомиться, начать общаться и встречаться в вашем городе. Бесплатная регистрация или вход без регистрации - через соцсети.'},
#  'znakomstva.net': {'domain': 'znakomstva.net',
#   'url': 'http://znakomstva.net',
#   'title': 'Знакомства и чат №1 для серьёзных отношений и без обязательств! - Znakomstva.Net',
#   'keywords': 'серьёзные, лёгкие, знакомства, сайт, чат, знакомств, без регистрации, для, серьёзных, лёгких, отношений, брака, создания семьи, с иностранцами, девушками, парнями, женщинами, мужчинами',
#   'description': 'Сайт и чат знакомств для серьёзных или лёгких отношений без обязательств, общения, дружбы, любви, встреч, брака и создания семьи. Вход бесплатный и без регистрации - через соц сети.'},
#  'znakomstva.filmykino.com': {'domain': 'znakomstva.filmykino.com',
#   'url': 'http://znakomstva.filmykino.com',
#   'title': 'filmykino.com\xa0-\xa0Informationen zum Thema filmykino.',
#   'keywords': None,
#   'description': 'filmykino.com ist die beste Quelle für alle Informationen die Sie suchen. Von allgemeinen Themen bis hin zu speziellen Sachverhalten, finden Sie auf filmykino.com alles. Wir hoffen, dass Sie hier das Gesuchte finden!'},
#  'znakomstva.besplatnye.net': {'domain': 'znakomstva.besplatnye.net',
#   'url': 'http://znakomstva.besplatnye.net',
#   'title': 'Hessen, Frankfurt am Main — Suchresultate — Знакомства без регистрации — сайт бесплатных знакомств по фото и чатом',
#   'keywords': 'бесплатные знакомства, сайт знакомств, знакомства без регистрации, вторая половинка, любовь, моя страница, фото знакомства, чат знакомств, секс знакомства, знакомства для серьезных отношений, гей знакомства, знакомства для брака, онлайн-знакомства, интернет знакомства, знакомства для флирта, быстрые знакомства',
#   'description': 'Бесплатные знакомства без регистрации с фото и чатом для секса, серьезных отношений, брака на своей странице.'},
#  'znakomstva-vkontakte.ru': {'domain': 'znakomstva-vkontakte.ru',
#   'url': 'http://znakomstva-vkontakte.ru',
#   'title': 'Блог №1 про знакомства в Контакте. Все о том, как познакомиться, что написать девушке.',
#   'keywords': 'знакомства в Контакте',
#   'description': 'Я хочу поделиться своими мыслями о знакомствах в Контакте с девушками и о том, что можно написать им, чтобы привлечь внимание и познакомиться'},
#  'znakomstva-spb.ru': {'domain': 'znakomstva-spb.ru',
#   'url': 'http://znakomstva-spb.ru',
#   'title': 'Брачное агентство "от Анатолия Ивановича" - БРАЧНОЕ АГЕНТСТВО СЛУЖБА ЗНАКОМСТВ ОТ АНАТОЛИЯ ИВАНОВИЧА Санкт-Петербург Dating and Marriage Agency “From Anatoly Ivanovich” Saint-Petersburg Брачные знакомства служба знакомств создание семьи брачное агентство брачные знакомства сваха мужчина',
#   'keywords': 'Dating and Marriage Agency znakomstva',
#   'description': 'Мы работаем в Санкт-Петербурге с апреля 2002 года. За это время сложилась эффективная методика работы с клиентами, дающая отличные результаты. О нас писали в газетах, показывали по телевидению Ежемесячно находят друг друга до 10 пар и более'},
#  'znakomstva-sitelove.ru': {'domain': 'znakomstva-sitelove.ru',
#   'url': 'http://znakomstva-sitelove.ru',
#   'title': 'SiteLove - знакомства для серьёзных отношений и брака!',
#   'keywords': 'сайт знакомств,знакомства,sitelove,серьёзные отношения,создание семьи,спутник жизни,брак,любовь,мужчины,девушки,анкеты,совместимость по знакам Зодиака',
#   'description': 'Сайт знакомств для поиска спутника жизни и второй половины, знакомства для брака и серьёзных отношений с учётом знака Зодиака и астрологической совместимости.'},
#  'znakomstva-rf.ru': {'domain': 'znakomstva-rf.ru',
#   'url': 'http://znakomstva-rf.ru',
#   'title': 'Знакомства на Znakomstva-Rf.Ru | сайт знакомства | знакомства | знакомства в городе | бесплатные знакомства | знакомства бесплатно | знакомства рф',
#   'keywords': 'знакомства, сайт знакомства, знакомства без регистрации, бесплатные знакомства, знакомства москва, серьезные отношения, сайт знакомства без регистрации',
#   'description': 'Сайт знакомств Znakomstva-Rf.Ru это анкеты девушек и парней со всего света. Регистрируйтесь и начинайте знакомиться и получать удовольствие от общения! Для пользователей социальных сетей: speed dating знакомства без регистрации.'},
#  'znakomstva-loveplanet.ru': {'domain': 'znakomstva-loveplanet.ru',
#   'url': 'http://znakomstva-loveplanet.ru',
#   'title': 'Знакомства LovePlanet на znakomstva-loveplanet.ru | главная страница сайта "Знакомства-Лавпланет", бесплатные интернет-знакомства loveplanet, love planet сайт знакомств бесплатно, общение, встречи, дружба, любовь...',
#   'keywords': None,
#   'description': None},
#  'znakomstva-fotostrana.blogspot.ru': {'domain': 'znakomstva-fotostrana.blogspot.ru',
#   'url': 'http://znakomstva-fotostrana.blogspot.ru',
#   'title': 'Фотострана знакомства моя страница',
#   'keywords': 'фотострана вход, фотострана сайт знакомств, мобильная версия фотостраны, добавить в чёрный список на фотостране, сайт знакомств, вход на фотострану, fotostrana_1',
#   'description': 'Блог Фотострана. Здесь лайфхаки, полезные советы, отзывы пользователей сайта и приложения.'},
#  'znakomka.ru': {'domain': 'znakomka.ru',
#   'url': 'http://znakomka.ru',
#   'title': 'Afrique du Sud \xa0: résultats de la recherche\xa0: Знакомства на Znakomka.ru',
#   'keywords': None,
#   'description': None},
#  'znakomka.ledistrana.ru': {'domain': 'znakomka.ledistrana.ru',
#   'url': 'http://znakomka.ledistrana.ru',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host znakomka.ledistrana.ru:80 ssl:None [nodename nor servname provided, or not known]'},
#  'znakomiy.ru': {'domain': 'znakomiy.ru',
#   'url': 'http://znakomiy.ru',
#   'title': 'ЗНАКОМЫЙ.ru - сайт знакомств для всех: девушек, парней, пар. Знакомства для флирта, любви.',
# ...
#   'title': 'Citrix Hypervisor | Open Source Server Virtualization',
#   'keywords': 'virtualization, open source, cloud computing, server virtualization platform',
#   'description': "Citrix Hypervisor is the leading open source virtualization platform, powered by the Xen hypervisor. It is used in the world's largest clouds and enterprises."},
#  'xenon61.ru': {'domain': 'xenon61.ru',
#   'url': 'http://xenon61.ru',
#   'title': 'Xenon61 - ксеноновое оборудование, галогеновые и светодиодные лампы, дополнительная оптика, системы безопасности, дополнительное оборудование, автозвук, аккумуляторы - интернет-магазин и установочный центр Xenon61 Ростов-на-Дону',
#   'keywords': None,
#   'description': None},
#  'xela.ru': {'domain': 'xela.ru',
#   'url': 'http://xela.ru',
#   'title': 'Авторский блог Капитохина Александра',
#   'keywords': None,
#   'description': 'Xela.ru, блог о фотографии. Рассказываю о технике, съемке и обработке фотографий. Даю уроки фотошоп (Photoshop).'},
#  'xedos6.su': {'domain': 'xedos6.su',
#   'url': 'http://xedos6.su',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host xedos6.su:80 ssl:None [nodename nor servname provided, or not known]'},
#  'xebox.ru': {'domain': 'xebox.ru',
#   'url': 'http://xebox.ru',
#   'title': 'Как построить курятник своими руками',
#   'keywords': None,
#   'description': None},
#  'xeberci.org': {'domain': 'xeberci.org',
#   'url': 'http://xeberci.org',
#   'title': 'xeberci.org\xa0-&nbspThis website is for sale!\xa0-&nbspxeberci Resources and Information.',
#   'keywords': None,
#   'description': 'This website is for sale! xeberci.org is your first and best source for all of the information you’re looking for. From general topics to more of what you would expect to find here, xeberci.org has it all. We hope you find what you are searching for!'},
#  'xe.com': {'domain': 'xe.com',
#   'url': 'http://xe.com',
#   'title': "XE - The World's Trusted Currency Authority: Money Transfers & Free Exchange Rate Tools",
#   'keywords': 'exchange rates, currency exchange, currency rates, currency services, currency traders, currency trading, currency transfers, best exchange rates, rates, convert, currencies, currency, forex, forex news, forex terms, central bank rates, charting, charts, choosing a broker, commerce, discount, efficient, foreign exchange, foreign exchange payment, save money, save time, free, fx, global, global economy, glossary, graphs, guaranteed, headlines, introduction to forex, live, mid-market, trade currency, xe money transfer, articles, accurate rates, accounting, expense management, xe Datafeed, forex markets'},
#  'xd.mail.ru': {'domain': 'xd.mail.ru',
#   'url': 'http://xd.mail.ru',
#   'title': '404 Not Found',
#   'keywords': None,
#   'description': None},
#  'xboxlive.cardcodes.net': {'domain': 'xboxlive.cardcodes.net',
#   'url': 'http://xboxlive.cardcodes.net',
#   'title': 'Free Xbox Live Gold 12 Month Upgrade',
#   'keywords': 'free xbox live gold, xbox live gold codes, xbl gold, xbox live gold, xbox live gold for free, 12 months xbox live free',
#   'description': 'We have free Xbox Live Gold codes for everyone! Supplies are extremely limited so get yours now before we run out of stock!'},
#  'xboxland.net': {'domain': 'xboxland.net',
#   'url': 'http://xboxland.net',
#   'title': None,
#   'keywords': None,
#   'error': 'Not all data available'},
#  'xbox.su': {'domain': 'xbox.su',
#   'url': 'http://xbox.su',
#   'title': 'XBOX.SU - новости мира Xbox',
#   'keywords': None,
#   'description': 'новости мира Xbox'},
#  'xbabe.com': {'domain': 'xbabe.com',
#   'url': 'http://xbabe.com',
#   'title': 'XBabe Tube - Nude models, hot free erotic and porn videos',
#   'keywords': 'adult, free, porn, sex, erotic, nude, babes, girls, models, teens, pornstars, tube, streaming, videos, movies, clips, scenes, xbabe, xxx babes, ex brandigirls.com',
#   'description': "XBabe.com brings you the most beautiful women in the world, updated daily. Each erotic goddess and sexy solo girl poses, plays, and sometimes masturbates to arouse you. The young models wear lingerie, hot outfits, and nothing at all. There's occasional girl on girl a and hardcore sex to arouse."},
#  'xarman.com': {'domain': 'xarman.com',
#   'url': 'http://xarman.com',
#   'title': None,
#   'keywords': None,
#   'error': 'Connection refused'},
#  'xalyava.tv': {'domain': 'xalyava.tv',
#   'url': 'http://xalyava.tv',
#   'title': None,
#   'keywords': None,
#   'description': None},
#  'xaker26.com': {'domain': 'xaker26.com',
#   'url': 'http://xaker26.com',
#   'title': None,
#   'keywords': None,
#   'description': None},
#  'xakep.ru': {'domain': 'xakep.ru',
#   'url': 'http://xakep.ru',
#   'title': '«Хакер» - Безопасность, разработка, DevOps',
#   'keywords': None,
#   'description': 'Безопасность, разработка, DevOps'},
#  'xakep.co': {'domain': 'xakep.co',
#   'url': 'http://xakep.co',
#   'title': None,
#   'keywords': None,
#   'description': None},
#  'xai-tec.webprorab.com': {'domain': 'xai-tec.webprorab.com',
#   'url': 'http://xai-tec.webprorab.com',
#   'title': 'Интернет-магазин "Хайтек ООО"',
#   'keywords': 'Компания Хайтек ООО, описание деятельности, контактные данные, телефон, адрес, предоставляемые товары и услуги',
#   'description': ''},
#  'xage.ru': {'domain': 'xage.ru',
#   'url': 'http://xage.ru',
#   'title': 'Молодежный портал - фото, гаджеты, дизайн, игры, авто, спорт, фильмы',
#   'keywords': 'блог, авто, медиа, фото, дизайн, идеи, гаджеты, молодежь, xage',
#   'description': 'Молодежный портал - фото, гаджеты, дизайн, игры, авто, спорт, фильмы ☛ Читать на Xage.ru'},
#  'xa-xa.org': {'domain': 'xa-xa.org',
#   'url': 'http://xa-xa.org',
#   'title': 'Приколы на XA-XA.ORG: Тысячи фото, картинки, анекдоты, видео, флеш и других приколов!',
#   'keywords': 'приколы, фото, видео, анекдоты, шутки, юмор, картинки, фотографии, флеш, истории, sms, масяня, наша раша, камеди, смех, коры, фишки',
#   'description': 'На сайте xa-xa.org вас ждут самые популярные приколы сети. Здесь вы найдете множество анекдотов- фото- видео- флеш- и других приколов. Если вы устали от проблем, забот или просто загрустили, то загляните на сайт ха-ха.org. Всего за пять минут вы получите заряд положительных эмоций! А хорошее настроение и улыбка не оставят грусти ни единого шанса!'},
#  'x3mboardshop.ru': {'domain': 'x3mboardshop.ru',
#   'url': 'http://x3mboardshop.ru',
#   'title': 'Спортивный интернет магазин | Бордшоп x3mSHOP',
#   'keywords': None,
#   'description': None},
#  'x-zone.com.ua': {'domain': 'x-zone.com.ua',
#   'url': 'http://x-zone.com.ua',
#   'title': 'Туристическое снаряжение, товары для туризма и активного отдыха купить в Киеве, цена, отзывы 2018 - туристический интернет магазин X-Zone - Киев Украина',
#   'keywords': '',
#   'description': 'Лучшие цены на товары для туризма и отдыха в туристическом магазине X-Zone ✓ Более 20 000 товаров ✓Гарантия ✓100% оригинал ✓Описания и фото ✓Обзоры и отзывы ✓Акции и скидки ⛟Доставка по Украине ☎(044) 303-98-85'},
#  'x-true.info': {'domain': 'x-true.info',
#   'url': 'http://x-true.info',
#   'title': 'Сила в ПРАВДЕ: Актуальные международные новости',
#   'keywords': 'международная политика, Россия, Украина, война на Донбассе, военные материалы,  СССР,  ток-шоу, видео,',
#   'description': 'Только самые свежие и актуальные новости за последний час, сутки и неделю.'},
#  'x-torrents.org': {'domain': 'x-torrents.org',
#   'url': 'http://x-torrents.org',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host x-torrents.org:80 ssl:None [nodename nor servname provided, or not known]'},
#  'x-time.info': {'domain': 'x-time.info',
#   'url': 'http://x-time.info',
#   'title': 'x-time.info',
#   'keywords': None,
#   'description': None},
#  'x-steel.ru': {'domain': 'x-steel.ru',
#   'url': 'http://x-steel.ru',
#   'title': [],
#   'keywords': None,
#   'description': 'width=device-width, initial-scale=1'},
#  'x-star.ru': {'domain': 'x-star.ru',
#   'url': 'http://x-star.ru',
#   'title': 'Порнозвезды!',
#   'keywords': None,
#   'description': 'Сайт, посвященный порнозвездам'},
#  'x-sobaka.ru': {'domain': 'x-sobaka.ru',
#   'url': 'http://x-sobaka.ru',
#   'title': 'Интернет-магазин зоотоваров  ЗОО-ГРАД',
#   'keywords': 'аренда вольера, Вольер для щенков, вольер для щенков купить, вольер для щенков в квартиру, вольеры для собак, вольеры для собак фото, вольер для квартиры, домашние вольеры для собак, вольер, клетка для собаки, клетки для собак, домашняя клетка, аренда клетки, зоотовары, корм, переноска, переноски, боксы, перегородки, лежанка, лежанки, будка, будки, многоразовые пеленки, многоразовая пеленка, талисмед',
#   'description': 'Клетки, вольеры, перегородки, переноски, родильные манежи и прочие зоотовары. Аренда вольеров. Быстрая доставка. Мега-выбор: 30000+ товаров!'},
#  'x-niva.net': {'domain': 'x-niva.net',
#   'url': 'http://x-niva.net',
#   'title': 'Шевроле нива (Chevrolet Niva) на дорогах и вне дорог... || Сайт о Шевроле Ниве (Chevrolet Niva)',
#   'keywords': None,
#   'description': None},
#  'x-minx.com': {'domain': 'x-minx.com',
#   'url': 'http://x-minx.com',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host x-minx.com:80 ssl:None [nodename nor servname provided, or not known]'},
#  'x-minus.org': {'domain': 'x-minus.org',
#   'url': 'http://x-minus.org',
#   'title': '',
#   'keywords': None,
#   'description': None},
#  'x-faq.ru': {'domain': 'x-faq.ru',
#   'url': 'http://x-faq.ru',
#   'title': 'Форум о Свободной Энергии x-F.A.Q. - Главная страница',
#   'keywords': 'альтернативная энергетика, ветрогенераторы, гидрогенераторы, солнечная энергия, экология, свободная энергия, free energy, Тесла, БТГ, бестопливные генераторы, резонанс, Капанадзе, Смит, катушка Тесла, вечный двигатель, СЕ, резонанс Мельниченко, электролиз, альтернативная история, саморазвитие',
#   'description': 'Форум о Свободной Энергии x-F.A.Q. - Главная страница'},
#  'x-drivers.ru': {'domain': 'x-drivers.ru',
#   'url': 'http://x-drivers.ru',
#   'title': 'Новости, статьи, каталог драйверов и прошивок: XDRV.RU',
#   'keywords': 'драйверы,принтеры,скачать,download,бесплатный каталог,новости,статьи,MP3 плееры,прошивки,BIOS',
#   'description': 'Новости, статьи, каталог драйверов и прошивок: XDRV.RU. Ежедневные новости и свежие обзоры актуальных смартфонов, планшетов и софта'},
#  'x-console.com': {'domain': 'x-console.com',
#   'url': 'http://x-console.com',
#   'title': 'x-console.com\xa0-&nbspInformationen zum Thema x-console.',
#   'keywords': None,
#   'description': 'x-console.com ist die beste Quelle für alle Informationen die Sie suchen. Von allgemeinen Themen bis hin zu speziellen Sachverhalten, finden Sie auf x-console.com alles. Wir hoffen, dass Sie hier das Gesuchte finden!'},
#  'x-centr.com': {'domain': 'x-centr.com',
#   'url': 'http://x-centr.com',
#   'title': 'Более 35 000 видео смотрите бесплатно на X-centr.net',
#   'keywords': None,
#   'description': 'Самые популярные порно видео мы разместили в более чем 200 категориях.Подбор порно по размеру сисек, форме попок и другим параметрам.Новые видео каждый день.'},
#  'x-bikers.ru': {'domain': 'x-bikers.ru',
#   'url': 'http://x-bikers.ru',
#   'title': 'X-Bikers.ru - горный велосипед, велотриал, фрирайд, стрит, дёрт, BMX',
#   'keywords': None,
#   'description': None},
#  'wyta.ru': {'domain': 'wyta.ru',
#   'url': 'http://wyta.ru',
#   'title': 'Каталог сайтов с прямыми ссылками, мы не требуем обратного размещения обратной ссылки',
#   'keywords': None,
#   'description': 'Каталог сайтов, рейтинг, скриншоты сайтов, прямые ссылки сайтов. Добавить сайт в каталог.'},
#  'wwwwhatsapp-ru.com': {'domain': 'wwwwhatsapp-ru.com',
#   'url': 'http://wwwwhatsapp-ru.com',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host wwwwhatsapp-ru.com:80 ssl:None [nodename nor servname provided, or not known]'},
#  'wwwru.at.ua': {'domain': 'wwwru.at.ua',
#   'url': 'http://wwwru.at.ua',
#   'title': 'WWW - САМЫЕ ПОПУЛЯРНЫЕ WWW - НОВОСТИ WWW',
#   'keywords': 'www, сайт',
#   'description': 'WWW - КАТАЛОГ, ОФИЦИАЛЬНЫЕ САЙТЫ, САЙТ, БРЕНД, МАГАЗИН, ЗНАКОМСТВА, ГОРОД, ОТДЫХ, ПОГОДА, ВЛАСТЬ, АВТОМОБИЛЬ'},
#  'wwwleto.moy.su': {'domain': 'wwwleto.moy.su',
#   'url': 'http://wwwleto.moy.su',
#   'title': 'Любители Путешествий - Автобусные туры на черное море из Тольятти и Самары - Автобусные туры в Крым из Тольятти и Самары - Горящие туры от Турагентства "ЛЕТО" г.Тольятти.',
#   'keywords': None,
#   'description': None},
#  'www8.wgcshop.com': {'domain': 'www8.wgcshop.com',
#   'url': 'http://www8.wgcshop.com',
#   'title': None,
#   'keywords': None,
#   'error': 'Cannot connect to host www8.wgcshop.com:80 ssl:None [nodename nor servname provided, or not known]'},
#  'www73.zippyshare.com': {'domain': 'www73.zippyshare.com',
#   'url': 'http://www73.zippyshare.com',
#   'title': '403 Forbidden',
#   'keywords': None,
#   'description': None},
#  'www64.zippyshare.com': {'domain': 'www64.zippyshare.com',
#   'url': 'http://www64.zippyshare.com',
#   'title': '403 Forbidden',
#   'keywords': None,
#   'description': None},
#  'www59.zippyshare.com': {'domain': 'www59.zippyshare.com',
#   'url': 'http://www59.zippyshare.com',
#   'title': '403 Forbidden',
#   'keywords': None},
#  'www50.zippyshare.com': {'domain': 'www50.zippyshare.com',
#   'url': 'http://www50.zippyshare.com',
#   'title': '403 Forbidden',
#   'keywords': None,
#   'description': None},
#  'www5.at.ua': {'domain': 'www5.at.ua',
#   'url': 'http://www5.at.ua',
#   'title': 'Каталог популярных сайтов - Главная страница',
#   'keywords': None,
#   'description': None},
#  'www47.zippyshare.com': {'domain': 'www47.zippyshare.com',
#   'url': 'http://www47.zippyshare.com',
#   'title': '403 Forbidden',
#   'keywords': None,
#   'description': None},
#  'www45.zippyshare.com': {'domain': 'www45.zippyshare.com',
#   'url': 'http://www45.zippyshare.com',
#   'title': '403 Forbidden',
#   'keywords': None,
#   'description': None},
#  'www40.zippyshare.com': {'domain': 'www40.zippyshare.com',
#   'url': 'http://www40.zippyshare.com',
#   'title': '403 Forbidden',
#   'keywords': None,
#   'description': None},
#  'www34.zippyshare.com': {'domain': 'www34.zippyshare.com',
#   'url': 'http://www34.zippyshare.com',
#   'title': '403 Forbidden',
#   'keywords': None,
#   'description': None},
#  'www31.zippyshare.com': {'domain': 'www31.zippyshare.com',
#   'url': 'http://www31.zippyshare.com',
#   'title': '403 Forbidden',
#   'keywords': None},
#  'www3.royalmail.com': {'domain': 'www3.royalmail.com',
#   'url': 'http://www3.royalmail.com',
#   'title': 'Royal Mail | Royal Mail Group Ltd',
#   'keywords': 'Royal Mail, Royalmail, post, stamps, letters, mail, parcels, packages, stamp collecting, philatelic, philately, postcodes online, post codes, postcodes,uk postcodes, postcodes on-line, postcode finder, post code finder postcode, address finder, find address, postal rates, find postcode, post shop, shop, mailing services, postal services, tariffs, special delivery, postal tariffs, business mail, business post, Consignia',
#   'description': "Royal Mail is the UK's most trusted letters and parcels delivery company. We  provide a 6-days-a-week, one-price-goes anywhere postal service across the UK."},
#  'www28.zippyshare.com': {'domain': 'www28.zippyshare.com',
#   'url': 'http://www28.zippyshare.com',
#   'title': '403 Forbidden',
#   'keywords': None,
#   'description': None},
#  'www27.zippyshare.com': {'domain': 'www27.zippyshare.com',
#   'url': 'http://www27.zippyshare.com',
#   'title': '403 Forbidden',
#   'keywords': None,
#   'description': None},
#  'www2.kenes.com': {'domain': 'www2.kenes.com',
#   'url': 'http://www2.kenes.com',
#   'title': None,
#   'keywords': None,
#   'error': 'Not all data available'},
#  'www2.clustrmaps.com': {'domain': 'www2.clustrmaps.com',
#   'url': 'http://www2.clustrmaps.com',
#   'title': 'Free Website Counter Showing Visitor Location on Map',
#   'keywords': None,
#   'description': 'Accurate hit counter with the most appropriate visualization'},
#  'www11.zippyshare.com': {'domain': 'www11.zippyshare.com',
#   'url': 'http://www11.zippyshare.com',
#   'title': '403 Forbidden',
#   'keywords': None,
#   'description': None},
#  'www1.search.ask.com': {'domain': 'www1.search.ask.com',
#   'url': 'http://www1.search.ask.com',
#   'title': 'Search',
#   'keywords': None,
#   'description': None},
#  ...}

# %%
len(results)
# Out:
# 75608

# %% [markdown]
# ## Чистим полученные данные

# %% [markdown]
# ##### получила через вот такую команду
#
# cat content_bigdata10_proj1_kek/data/titles-aiohttp.json | jq '.[] | .title' | sort | uniq -c | sort -rn | head

# %%
bad_titles = ['403 Forbidden',
'404 - Ladefehler der Webseite',
'404 - Unable to load website',
'Loading...',
'Главная',
'410 - Website deleted',
'404 Not Found',
'— @дневники: асоциальная сеть',
'404 - Impossible de télécharger le site',
'Главная страница',
'404 - Не удалось загрузить сайт',
'Just a moment...',
'Персональный сайт - Главная страница',
'Welcome!',
'502 Bad Gateway',
'503 Service Temporarily Unavailable',
'Этот домен припаркован компанией Timeweb',
'Домен не прилинкован ни к одной из директорий на сервере!',
'Attention Required! | Cloudflare',
'Konto ist gesperrt',
'Apache HTTP Server Test Page powered by CentOS',
'Ошибка при открытии страницы',
'Welcome to nginx!',
'Index of /',
'Срок регистрации домена закончился. Купить домен можно тут.',
'Ресурс заблокирован - Resource is blocked',
'Работа сайта временно приостановлена',
'В ближайшие сутки работа сайта восстановится.',
'Персональный сайт - Главная',
'[.m] masterhost - профессиональный хостинг сайта',
'Waiting for the redirectiron...',
'job.ru переехал на hh.ru',
'Account disabled by server administrator',
'Этот сайт заблокирован',
'Ведутся технические работы',
'Account Suspended',
'Error 404 (Not Found)!!1',
'404 - Not Found',
'Этот домен продаётся',
'500 Internal Server Error',
'Access Denied',
'Истёк срок регистрации домена\xa0zubovskaya-banya.ru']

# %%
# %%time
clean_results = {}
for result in results:
    if (results[result]['title'] not in bad_titles) and \
    (results[result]['title'] is not None or results[result]['keywords'] is not None):
        clean_results[result] = results[result]
# Out:
# CPU times: user 130 ms, sys: 3.76 ms, total: 134 ms
# Wall time: 136 ms

# %%
len(clean_results)
# Out:
# 65328

# %%
# titles = []
# keywords = []
# descriptions = []
# for domain in clean_results:
#     titles.append(clean_results[domain].get('title', ''))
#     keywords.append(clean_results[domain].get('keywords', ''))
#     descriptions.append(clean_results[domain].get('description', ''))

# %%
#counts_keywords = Counter(keywords)
#top30_keywords =  sorted(list(counts_keywords.items()), key=lambda tup: tup[1], reverse=True)[:30]

# %% [markdown]
# #### train texts

# %%
# %%time

dom_info = []
for domain in clean_results:
    info = str(clean_results[domain].get('title', '')) \
         + str(clean_results[domain].get('keywords', '')) \
         + str(clean_results[domain].get('description', ''))
    dom_info.append([domain, info])
# Out:
# CPU times: user 1.01 s, sys: 309 ms, total: 1.32 s
# Wall time: 1.51 s

# %%
len(dom_info)
# Out:
# 65328

# %% [markdown]
# Делаю предобработку по частям, ибо постоянно ловила broken pipe. Вообще все в одну функцию запихнуть можно.

# %%
def text_to_wordlist(text):
    text = re.sub('[^a-zA-Zа-яА-ЯёЁ]', ' ', text)
    text = re.sub('none', ' ', text.lower())
    words = text.lower().strip().split()
    return words

# %%
def clean(words, stopWords):
    new_words = [word for word in words if (word not in stopWords) and len(word) > 2]
    return new_words

# %%
mystem = pymystem3.Mystem()
wordnet_lemmatizer = WordNetLemmatizer()
def clean_v2(words):    
    new_words = [mystem.lemmatize(x)[0] for x in words]
    new_new_words = [wordnet_lemmatizer.lemmatize(x, pos=wordnet.VERB) for x in new_words]
    return new_new_words

# %%
domain_info = pd.DataFrame(data=dom_info, columns=['domain', 'info'])

# %%
#берем только буквы + split по пробелам
domain_info['norm_info'] = domain_info['info'].apply(lambda x: text_to_wordlist(x))

# %%
# %%time
#убираем стоп-слова + убираем слова длинной <= 2
stopWords = stopwords.words(['russian', 'english'])
domain_info['norm_info_v2'] = domain_info['norm_info'].apply(lambda x: clean(x, stopWords))
# Out:
# CPU times: user 9.37 s, sys: 91 ms, total: 9.46 s
# Wall time: 9.9 s

# %%
# %%time
#лемматизация
domain_info['norm_info_v3'] = domain_info['norm_info_v2'].apply(lambda x: clean_v2(x))
# Out:
# CPU times: user 1min 11s, sys: 22.2 s, total: 1min 33s
# Wall time: 3min 25s

# %%
# %%time
#берем уникальные слова для домена
domain_info['norm_info_v4'] = domain_info['norm_info_v3'].apply(lambda x: list(set(x)))
# Out:
# CPU times: user 314 ms, sys: 28.3 ms, total: 342 ms
# Wall time: 364 ms

# %%
#убираем домены без инфы
domain_info['is_empty'] = domain_info['norm_info_v4'].apply(lambda x: 0 if x else 1)
domain_info = domain_info[domain_info['is_empty'] == 0]

# %%
domain_info.shape
# Out:
# (64285, 7)

# %%
domain_info.head()
# Out:
#             domain                                               info  \
# 0  эфирныемасла.рф  Интернет магазин эфирных масел, аромакосметики...
# 1        эролюб.рф  Эролюб.рф - страстные знакомства для взрослых ...
# 2   шарикиоптом.рф  Фитолампы, фитосветильники, прожекторы для рас...
# 3     чинамобил.рф  Каталог запчастей CHERY GEELY LIFAN Brilliance...
# 4       чекиспб.рф                      Любые чеки СПб! - ГлавнаяNone
#
#                                            norm_info  \
# 0  [интернет, магазин, эфирных, масел, аромакосме...
# 1  [эролюб, рф, страстные, знакомства, для, взрос...
# 2  [фитолампы, фитосветильники, прожекторы, для, ...
# 3  [каталог, запчастей, chery, geely, lifan, bril...
# 4                        [любые, чеки, спб, главная]
#
#                                         norm_info_v2  \
# 0  [интернет, магазин, эфирных, масел, аромакосме...
# 1  [эролюб, страстные, знакомства, взрослых, реал...
# 2  [фитолампы, фитосветильники, прожекторы, расте...
# 3  [каталог, запчастей, chery, geely, lifan, bril...
# 4                        [любые, чеки, спб, главная]
#
#                                         norm_info_v3  \
# 0  [интернет, магазин, эфирный, масло, аромакосме...
# 1  [эролюб, страстный, знакомство, взрослый, реал...
# 2  [фитолампа, фитосветильник, прожектор, растени...
# 3  [каталог, запчасть, chery, geely, lifan, brill...
# 4                         [любой, чек, спб, главный]
#
#                                         norm_info_v4  is_empty
# 0  [эфирный, масло, интернет, магазин, ирис, аром...         0
# 1  [страстный, сайт, фото, романтик, реальный, жи...         0
# 2  [фитолампа, весь, гроубокс, аквариум, растение...         0
# 3  [черя, автомобиль, комплектующий, chery, brill...         0
# 4                         [главный, чек, спб, любой]         0

# %%
domain_dict = dict(zip(domain_info.domain, domain_info.norm_info_v4))

# %%
#еще надо убрать всякую муть типа "домен продается"

# %% [markdown]
# ## Bag of words for user

# %% [markdown]
# Каждому юзеру присоединяем его список слов по списку доменов

# %%
def bag_of_words_for_user(norm_domain_list, domain_dict):
    bag_of_words = []
    for dom in norm_domain_list:
        try:
            bag_of_words.append(domain_dict[dom])
        except: 
            pass
    return sum(bag_of_words, [])

# %%
# %%time
df['bag_of_words'] = df['norm_domain_list'].apply(lambda x: bag_of_words_for_user(x, domain_dict))
# Out:
# CPU times: user 2min, sys: 10.9 s, total: 2min 11s
# Wall time: 2min 13s

# %%
df.head()
# Out:
#   gender    age                                   uid  \
# 0      F  18-24  d50192e5-c44e-4ae8-ae7a-7cfe67c8b777
# 1      M  25-34  d502331d-621e-4721-ada2-5d30b2c3801f
# 2      F  25-34  d50237ea-747e-48a2-ba46-d08e71dddfdb
# 3      F  25-34  d502f29f-d57a-46bf-8703-1cb5f8dcdf03
# 4      M   >=55  d503c3b2-a0c2-4f47-bb27-065058c73008
#
#                                            user_json  \
# 0  {'visits': [{'url': 'http://zebra-zoya.ru/2000...
# 1  {'visits': [{'url': 'http://sweetrading.ru/?p=...
# 2  {'visits': [{'url': 'http://ru.oriflame.com/pr...
# 3  {'visits': [{'url': 'http://translate-tattoo.r...
# 4  {'visits': [{'url': 'https://mail.rambler.ru/#...
#
#                                          domain_list  \
# 0  [b'zebra-zoya.ru', b'news.yandex.ru', b'sotovi...
# 1  [b'sweetrading.ru', b'sweetrading.ru', b'sweet...
# 2  [b'ru.oriflame.com', b'ru.oriflame.com', b'ru....
# 3  [b'translate-tattoo.ru', b'nadietah.ru', b'1ob...
# 4  [b'mail.rambler.ru', b'news.rambler.ru', b'mai...
#
#                                     norm_domain_list  gender_cat  age_cat  \
# 0  [zebra-zoya.ru, news.yandex.ru, sotovik.ru, ne...           0        0
# 1  [sweetrading.ru, sweetrading.ru, sweetrading.r...           1        1
# 2  [ru.oriflame.com, ru.oriflame.com, ru.oriflame...           0        1
# 3  [translate-tattoo.ru, nadietah.ru, 1obl.ru, 1o...           0        1
# 4  [mail.rambler.ru, news.rambler.ru, mail.ramble...           1        4
#
#                                            time_list  visits  time_range  \
# 0  [1419688144068, 1426666298001, 1426666298000, ...       5  6978153933
# 1  [1419717886224, 1419717884437, 1419717816375, ...     102  2266588550
# 2  [1418840296062, 1418667832733, 1418667717223, ...      44  8284914026
# 3  [1418217864467, 1418124701342, 1417866007812, ...      14   693126229
# 4  [1427272415001, 1427272415000, 1427271294001, ...     212   613917001
#
#      visit_rate  unique_domains_cnt  tot_domains_cnt  avg_visits_per_domain  \
# 0  1.395631e+09                   3                5               1.666667
# 1  2.222146e+07                  26              102               3.923077
# 2  1.882935e+08                   6               44               7.333333
# 3  4.950902e+07                   3               14               4.666667
# 4  2.895835e+06                  25              212               8.480000
#
#                                         bag_of_words
# 0  [интернет, магазин, ребенок, креативный, много...
# 1  [весь, торги, трейдер, forexторги, полезный, ф...
# 2  [cosmetics, oriflame, cosmetics, oriflame, cos...
# 3  [профессиональный, перевод, живой, переводсерв...
# 4  [надежный, весь, спам, несколько, почтовый, бе...

# %% [markdown]
# ## Get features from Bag Of Words

# %% [markdown]
# Берем топ 3000 слов из датафрейма с юзерами df (датафрейм, в котором 1 строка = 1 юзер), т.к. если брать из domain_info (датафрем, в котором 1 строка = 1 домен), то получается всякий шлак.

# %%
# %%time
df['bag_of_words_text'] = df['bag_of_words'].apply(lambda x: str(' '.join(x)).strip())
# Out:
# CPU times: user 4.08 s, sys: 1.24 s, total: 5.33 s
# Wall time: 6.45 s

# %%
#можно сюда еще какие-нибудь слова добавить, которые покажутся лишними
bad_words = ['домен', 'укр', 'рер', 'рес', 'регистрация', 'истекать', 'www', 
             'domain', 'многое', 'net', 'ооо', 'наш', 'опт', 'website', 'сайт', 'com',
             'ваш', 'который', 'это', 'современный', 'различный', 'разный', 'любой', 'хотеть','возможность',
             'собирать']

stopWords = stopwords.words(['russian', 'english'])
stopWords.extend(bad_words)

# %%
# %%time

#получим список слов, которые будем далее рассматривать (чтобы без всякого мусора)
count_vect_user = CountVectorizer(max_features=3000, stop_words=stopWords)
temp_matrix_user = count_vect_user.fit_transform(df['bag_of_words_text'].values) 
                                             
matrix_counts = temp_matrix_user.toarray()
# Out:
# CPU times: user 1min 18s, sys: 4.88 s, total: 1min 22s
# Wall time: 1min 27s

# %%
#список слов, которые будем в bigARTM учитывать
good_words = [x[0] for x in sorted(count_vect_user.vocabulary_.items(), key=lambda x: x[1])]

# %% [markdown]
# Обучаем CountVectorizer для датафрейма domain_info, чтобы на вход модели подать.

# %%
# %%time
norm_info = domain_info.norm_info_v3.tolist()
domain_info['good_words'] = [list(filter(lambda x: x in good_words, sublist)) for sublist in norm_info]
# Out:
# CPU times: user 1min 6s, sys: 7.87 s, total: 1min 14s
# Wall time: 1min 17s

# %%
domain_info.head(3)
# Out:
#             domain                                               info  \
# 0  эфирныемасла.рф  Интернет магазин эфирных масел, аромакосметики...
# 1        эролюб.рф  Эролюб.рф - страстные знакомства для взрослых ...
# 2   шарикиоптом.рф  Фитолампы, фитосветильники, прожекторы для рас...
#
#                                            norm_info  \
# 0  [интернет, магазин, эфирных, масел, аромакосме...
# 1  [эролюб, рф, страстные, знакомства, для, взрос...
# 2  [фитолампы, фитосветильники, прожекторы, для, ...
#
#                                         norm_info_v2  \
# 0  [интернет, магазин, эфирных, масел, аромакосме...
# 1  [эролюб, страстные, знакомства, взрослых, реал...
# 2  [фитолампы, фитосветильники, прожекторы, расте...
#
#                                         norm_info_v3  \
# 0  [интернет, магазин, эфирный, масло, аромакосме...
# 1  [эролюб, страстный, знакомство, взрослый, реал...
# 2  [фитолампа, фитосветильник, прожектор, растени...
#
#                                         norm_info_v4  is_empty  \
# 0  [эфирный, масло, интернет, магазин, ирис, аром...         0
# 1  [страстный, сайт, фото, романтик, реальный, жи...         0
# 2  [фитолампа, весь, гроубокс, аквариум, растение...         0
#
#                                           good_words
# 0                         [интернет, магазин, масло]
# 1  [знакомство, взрослый, реальный, фото, серьезн...
# 2  [растение, цветок, система, освещение, аквариу...

# %%
# %%time
domain_info['good_words_text'] = domain_info['good_words'].apply(lambda x: str(' '.join(x)).strip())
# Out:
# CPU times: user 122 ms, sys: 26.9 ms, total: 149 ms
# Wall time: 154 ms

# %%
cv_dom = CountVectorizer()
temp_matrix_dom = cv_dom.fit_transform(domain_info['good_words_text'].values)
n_wd = temp_matrix_dom.T
vocabulary = cv_dom.get_feature_names()

# %%
# %%time

cv_words = [x[0] for x in sorted(cv_dom.vocabulary_.items(), key=lambda x: x[1])] 
cv_dom = pd.DataFrame(temp_matrix_dom.toarray() , columns=cv_words).head()
cv_dom['id_domain'] = domain_info['domain']
# Out:
# CPU times: user 2.56 s, sys: 2.11 s, total: 4.68 s
# Wall time: 5.48 s

# %% [markdown]
# ### BigARTM

# %% [markdown]
# https://github.com/bigartm/bigartm/blob/master/README.md

# %%
# %%time
bv = artm.BatchVectorizer(data_format='bow_n_wd',
                          n_wd=n_wd,
                          vocabulary=vocabulary)
# Out:
# CPU times: user 1min 8s, sys: 880 ms, total: 1min 9s
# Wall time: 1min 11s

# %%
# %%time

# количество тем
T = 30   
# Learn simple LDA model (or you can use advanced artm.ARTM)
model = artm.LDA(num_topics=T, dictionary=bv.dictionary, cache_theta = True)
model.fit_offline(bv, num_collection_passes=20)
# Out:
# CPU times: user 1min 6s, sys: 4.84 s, total: 1min 11s
# Wall time: 21.8 s

# %%
model.get_top_tokens()
# Out:
# [['профессиональный',
#   'образование',
#   'имя',
#   'хостинг',
#   'сервер',
#   'скидка',
#   'высокий',
#   'готовый',
#   'решение',
#   'реферат'],
#  ['хороший',
#   'украина',
#   'клуб',
#   'кино',
#   'группа',
#   'новинка',
#   'club',
#   'любитель',
#   'харьков',
#   'камера'],
#  ['ребенок',
#   'детский',
#   'здоровье',
#   'жизнь',
#   'красота',
#   'человек',
#   'питание',
#   'развитие',
#   'женский',
#   'диета'],
#  ['школа',
#   'урок',
#   'обучение',
#   'юридический',
#   'курсы',
#   'разработка',
#   'art',
#   'смс',
#   'комплекс',
#   'дизайн'],
#  ['отдых',
#   'тур',
#   'мода',
#   'отель',
#   'sie',
#   'путешествие',
#   'туризм',
#   'крым',
#   'гостиница',
#   'поздравление'],
#  ['оборудование',
#   'официальный',
#   'техника',
#   'спортивный',
#   'технология',
#   'бытовой',
#   'машина',
#   'цифровой',
#   'электроника',
#   'велосипед'],
#  ['дом',
#   'квартира',
#   'дома',
#   'блог',
#   'строительство',
#   'дизайн',
#   'реклама',
#   'интерьер',
#   'часы',
#   'дача'],
#  ['новость',
#   'мир',
#   'интересный',
#   'событие',
#   'спорт',
#   'последний',
#   'самый',
#   'свежий',
#   'культура',
#   'политика'],
#  ['игра',
#   'петербург',
#   'санкт',
#   'спб',
#   'телефон',
#   'тест',
#   'играть',
#   'мобильный',
#   'консультация',
#   'обзор'],
#  ['скачать',
#   'недвижимость',
#   'программа',
#   'книга',
#   'бесплатно',
#   'музыка',
#   'журнал',
#   'электронный',
#   'песня',
#   'библиотека'],
#  ['онлайн',
#   'бесплатно',
#   'фильм',
#   'смотреть',
#   'видео',
#   'бесплатный',
#   'сериал',
#   'качество',
#   'хороший',
#   'торрент'],
#  ['купить',
#   'москва',
#   'цена',
#   'доставка',
#   'заказ',
#   'продажа',
#   'производитель',
#   'магазин',
#   'весь',
#   'подарок'],
#  ['центр',
#   'запчасть',
#   'медицинский',
#   'производство',
#   'тюнинг',
#   'инструмент',
#   'автозапчасть',
#   'клиника',
#   'самара',
#   'диск'],
#  ['бесплатный',
#   'windows',
#   'свадебный',
#   'обои',
#   'свадьба',
#   'рабочий',
#   'красивый',
#   'стол',
#   'android',
#   'оформление'],
#  ['главный',
#   'мебель',
#   'русский',
#   'страница',
#   'материал',
#   'язык',
#   'порно',
#   'строительный',
#   'английский',
#   'кухня'],
#  ['помощь',
#   'собака',
#   'белье',
#   'защита',
#   'тело',
#   'военный',
#   'форма',
#   'животный',
#   'почта',
#   'морской'],
#  ['фото',
#   'видео',
#   'фотография',
#   'история',
#   'картинка',
#   'салон',
#   'народный',
#   'прикол',
#   'медицина',
#   'ресторан'],
#  ['game',
#   'online',
#   'free',
#   'news',
#   'web',
#   'download',
#   'world',
#   'site',
#   'best',
#   'software'],
#  ['каталог',
#   'город',
#   'карта',
#   'справочник',
#   'организация',
#   'область',
#   'кошка',
#   'телефон',
#   'адрес',
#   'предприятие'],
#  ['портал',
#   'форум',
#   'бизнес',
#   'статья',
#   'совет',
#   'лечение',
#   'информация',
#   'полезный',
#   'мир',
#   'информационный'],
#  ['россия',
#   'год',
#   'новый',
#   'день',
#   'погода',
#   'сегодня',
#   'цветок',
#   'рынок',
#   'растение',
#   'гороскоп'],
#  ['система',
#   'сеть',
#   'агентство',
#   'установка',
#   'торговый',
#   'создавать',
#   'ростов',
#   'социальный',
#   'создание',
#   'управление'],
#  ['магазин',
#   'интернет',
#   'одежда',
#   'обувь',
#   'женский',
#   'аксессуар',
#   'мужской',
#   'модный',
#   'футбол',
#   'платье'],
#  ['вопрос',
#   'схема',
#   'банк',
#   'российский',
#   'вязание',
#   'ответ',
#   'модель',
#   'вид',
#   'деньги',
#   'класс'],
#  ['рецепт',
#   'домашний',
#   'билет',
#   'блюдо',
#   'кулинарный',
#   'номер',
#   'условие',
#   'простой',
#   'камень',
#   'вкусный'],
#  ['объявление',
#   'продажа',
#   'автомобиль',
#   'авто',
#   'бесплатный',
#   'доска',
#   'частный',
#   'аренда',
#   'продавать',
#   'покупка'],
#  ['работа',
#   'ремонт',
#   'свой',
#   'поиск',
#   'вакансия',
#   'рука',
#   'находить',
#   'сервис',
#   'компьютер',
#   'сделать'],
#  ['porn',
#   'sex',
#   'free',
#   'tube',
#   'videos',
#   'movies',
#   'xxx',
#   'mature',
#   'казань',
#   'hot'],
#  ['знакомство',
#   'киев',
#   'секс',
#   'косметика',
#   'любовь',
#   'уход',
#   'женщина',
#   'девушка',
#   'волос',
#   'мужчина'],
#  ['товар',
#   'компания',
#   'услуга',
#   'отзыв',
#   'кредит',
#   'нижний',
#   'россия',
#   'информация',
#   'новгород',
#   'скидка']]

# %%
#соответсвие тем и ключевых слов (для интерпретации тем)
topic_words = dict(zip(model.get_theta().index, model.get_top_tokens()))

# %%
#матрица, в которой по строкам - темы, по столбцам - входные тексты (то есть у нас 1 столбец = 1 домен)
model.get_theta().head()
# Out:
#             19000     19001     19002     19003     19004     19005     19006  \
# topic_0  0.000654  0.000551  0.000885  0.306307  0.000323  0.111617  0.421976
# topic_1  0.132333  0.000160  0.000885  0.003031  0.000322  0.000390  0.000518
# topic_2  0.000661  0.000156  0.000885  0.003333  0.217653  0.000366  0.162358
# topic_3  0.000654  0.000147  0.184703  0.003061  0.000333  0.000368  0.252640
# topic_4  0.000654  0.000138  0.000885  0.003031  0.000320  0.000366  0.000554
#
#             19007     19008     19009    ...        25990     25991     25992  \
# topic_0  0.000449  0.000752  0.003031    ...     0.004348  0.001901  0.000426
# topic_1  0.273757  0.000799  0.003031    ...     0.004348  0.001892  0.039464
# topic_2  0.000449  0.000812  0.003030    ...     0.004348  0.001887  0.712535
# topic_3  0.000451  0.000755  0.003253    ...     0.004348  0.001887  0.083464
# topic_4  0.000449  0.000757  0.003031    ...     0.004348  0.001887  0.000412
#
#             25993     25994     25995     25996     25997     25998     25999
# topic_0  0.004348  0.000354  0.033333  0.004348  0.007693  0.000753  0.007693
# topic_1  0.439131  0.107181  0.033333  0.004348  0.007693  0.000783  0.007693
# topic_2  0.004348  0.001097  0.033333  0.004348  0.007692  0.000785  0.007693
# topic_3  0.004348  0.000353  0.033333  0.004351  0.007693  0.000766  0.007693
# topic_4  0.004348  0.000353  0.033333  0.004348  0.007692  0.000876  0.007693
#
# [5 rows x 64285 columns]

# %%
theta = model.get_theta().T
theta['domain'] = domain_info['domain'].values
theta.reset_index(drop=True, inplace=True)

# %%
theta.head()
# Out:
#     topic_0   topic_1   topic_2   topic_3   topic_4   topic_5   topic_6  \
# 0  0.000654  0.132333  0.000661  0.000654  0.000654  0.000661  0.066229
# 1  0.000551  0.000160  0.000156  0.000147  0.000138  0.000214  0.147771
# 2  0.000885  0.000885  0.000885  0.184703  0.000885  0.303151  0.000885
# 3  0.306307  0.003031  0.003333  0.003061  0.003031  0.003031  0.003031
# 4  0.000323  0.000322  0.217653  0.000333  0.000320  0.000320  0.000320
#
#     topic_7   topic_8   topic_9       ...         topic_21  topic_22  \
# 0  0.000654  0.000654  0.000666       ...         0.000654  0.146375
# 1  0.043515  0.000142  0.000159       ...         0.000162  0.000265
# 2  0.000885  0.000959  0.000946       ...         0.000885  0.178284
# 3  0.004084  0.003031  0.300533       ...         0.003031  0.003031
# 4  0.000378  0.000333  0.270602       ...         0.000320  0.000440
#
#    topic_23  topic_24  topic_25  topic_26  topic_27  topic_28  topic_29  \
# 0  0.000663  0.000657  0.001022  0.000665  0.000654  0.133742  0.001131
# 1  0.000178  0.000167  0.085540  0.075686  0.000136  0.000152  0.088793
# 2  0.000885  0.000885  0.000904  0.310609  0.000885  0.000885  0.000885
# 3  0.003031  0.003032  0.003031  0.003038  0.003031  0.003031  0.003031
# 4  0.000322  0.000324  0.000320  0.000320  0.000320  0.255499  0.000322
#
#             domain
# 0  эфирныемасла.рф
# 1        эролюб.рф
# 2   шарикиоптом.рф
# 3     чинамобил.рф
# 4       чекиспб.рф
#
# [5 rows x 31 columns]

# %% [markdown]
# Теперь сопоставим каждому пользователю его список доменов.
# Коэффициенты при темах суммируем.

# %%
topic_cols = list(topic_words.keys())

# %%
def user_interest(dom_list, theta):
    topic_vector = [0]*(theta.shape[1]-1)
    for domain in dom_list:
        try:
            topic_vector += theta[theta['domain'] == domain].values[0][:-1]
        except:
            pass
    return topic_vector

# %%
df.head()
# Out:
#   gender    age                                   uid  \
# 0      F  18-24  d50192e5-c44e-4ae8-ae7a-7cfe67c8b777
# 1      M  25-34  d502331d-621e-4721-ada2-5d30b2c3801f
# 2      F  25-34  d50237ea-747e-48a2-ba46-d08e71dddfdb
# 3      F  25-34  d502f29f-d57a-46bf-8703-1cb5f8dcdf03
# 4      M   >=55  d503c3b2-a0c2-4f47-bb27-065058c73008
#
#                                            user_json  \
# 0  {'visits': [{'url': 'http://zebra-zoya.ru/2000...
# 1  {'visits': [{'url': 'http://sweetrading.ru/?p=...
# 2  {'visits': [{'url': 'http://ru.oriflame.com/pr...
# 3  {'visits': [{'url': 'http://translate-tattoo.r...
# 4  {'visits': [{'url': 'https://mail.rambler.ru/#...
#
#                                          domain_list  \
# 0  [b'zebra-zoya.ru', b'news.yandex.ru', b'sotovi...
# 1  [b'sweetrading.ru', b'sweetrading.ru', b'sweet...
# 2  [b'ru.oriflame.com', b'ru.oriflame.com', b'ru....
# 3  [b'translate-tattoo.ru', b'nadietah.ru', b'1ob...
# 4  [b'mail.rambler.ru', b'news.rambler.ru', b'mai...
#
#                                     norm_domain_list  gender_cat  age_cat  \
# 0  [zebra-zoya.ru, news.yandex.ru, sotovik.ru, ne...           0        0
# 1  [sweetrading.ru, sweetrading.ru, sweetrading.r...           1        1
# 2  [ru.oriflame.com, ru.oriflame.com, ru.oriflame...           0        1
# 3  [translate-tattoo.ru, nadietah.ru, 1obl.ru, 1o...           0        1
# 4  [mail.rambler.ru, news.rambler.ru, mail.ramble...           1        4
#
#                                            time_list  visits  time_range  \
# 0  [1419688144068, 1426666298001, 1426666298000, ...       5  6978153933
# 1  [1419717886224, 1419717884437, 1419717816375, ...     102  2266588550
# 2  [1418840296062, 1418667832733, 1418667717223, ...      44  8284914026
# 3  [1418217864467, 1418124701342, 1417866007812, ...      14   693126229
# 4  [1427272415001, 1427272415000, 1427271294001, ...     212   613917001
#
#      visit_rate  unique_domains_cnt  tot_domains_cnt  avg_visits_per_domain  \
# 0  1.395631e+09                   3                5               1.666667
# 1  2.222146e+07                  26              102               3.923077
# 2  1.882935e+08                   6               44               7.333333
# 3  4.950902e+07                   3               14               4.666667
# 4  2.895835e+06                  25              212               8.480000
#
#                                         bag_of_words  \
# 0  [интернет, магазин, ребенок, креативный, много...
# 1  [весь, торги, трейдер, forexторги, полезный, ф...
# 2  [cosmetics, oriflame, cosmetics, oriflame, cos...
# 3  [профессиональный, перевод, живой, переводсерв...
# 4  [надежный, весь, спам, несколько, почтовый, бе...
#
#                                    bag_of_words_text
# 0  интернет магазин ребенок креативный многое дом...
# 1  весь торги трейдер forexторги полезный форекс ...
# 2  cosmetics oriflame cosmetics oriflame cosmetic...
# 3  профессиональный перевод живой переводсервис л...
# 4  надежный весь спам несколько почтовый бесконеч...

# %%
df_cols = ['uid', 'gender_cat', 'age_cat', 'time_list',
           'visits', 'time_range', 'visit_rate', 'unique_domains_cnt', 
           'tot_domains_cnt', 'avg_visits_per_domain']

# %%
# %%time

tmp = df.norm_domain_list.apply(pd.Series)\
.merge(df[['uid','norm_domain_list']], left_index = True, right_index = True)\
.drop(['norm_domain_list'], axis = 1)\
.melt(id_vars = ['uid'], value_name = 'domain')\
.drop('variable', axis = 1).dropna().reset_index(drop=True)
# Out:
# CPU times: user 1min 20s, sys: 25.7 s, total: 1min 46s
# Wall time: 1min 50s

# %%
# %%time
tmp2 = tmp.set_index('domain').join(theta.set_index('domain')).fillna(0).groupby(['uid']).sum().reset_index()
# Out:
# CPU times: user 12.5 s, sys: 3.16 s, total: 15.7 s
# Wall time: 15.5 s

# %%
# %%time
df_upd = df.set_index('uid').join(tmp2.set_index('uid')).reset_index()
# Out:
# CPU times: user 323 ms, sys: 466 ms, total: 790 ms
# Wall time: 713 ms

# %%
#получили фичи из BigARTM
df_upd.head(2)
# Out:
#                                     uid gender    age  \
# 0  d50192e5-c44e-4ae8-ae7a-7cfe67c8b777      F  18-24
# 1  d502331d-621e-4721-ada2-5d30b2c3801f      M  25-34
#
#                                            user_json  \
# 0  {'visits': [{'url': 'http://zebra-zoya.ru/2000...
# 1  {'visits': [{'url': 'http://sweetrading.ru/?p=...
#
#                                          domain_list  \
# 0  [b'zebra-zoya.ru', b'news.yandex.ru', b'sotovi...
# 1  [b'sweetrading.ru', b'sweetrading.ru', b'sweet...
#
#                                     norm_domain_list  gender_cat  age_cat  \
# 0  [zebra-zoya.ru, news.yandex.ru, sotovik.ru, ne...           0        0
# 1  [sweetrading.ru, sweetrading.ru, sweetrading.r...           1        1
#
#                                            time_list  visits    ...      \
# 0  [1419688144068, 1426666298001, 1426666298000, ...       5    ...
# 1  [1419717886224, 1419717884437, 1419717816375, ...     102    ...
#
#    topic_20  topic_21   topic_22  topic_23  topic_24  topic_25  topic_26  \
# 0  0.720798  0.012963   0.019755  0.012793  0.379969  0.012793  0.012793
# 1  0.824418  1.375952  16.978559  0.410539  0.410379  0.662424  6.530401
#
#    topic_27  topic_28   topic_29
# 0  0.012793  0.013258   0.012792
# 1  0.411401  0.410369  10.322586
#
# [2 rows x 47 columns]

# %%
df_upd.to_pickle('df_features.pkl', compression='bz2')

# %% [markdown]
# ## Train

# %%
new_df_cols = ['visits', 'time_range', 'visit_rate', 'unique_domains_cnt', 
           'tot_domains_cnt', 'avg_visits_per_domain']

# %%
features = list(new_df_cols) + list(theta.columns[:-1])
target = ['gender_cat']

# %%
def identity_tokenizer(text):
    return text

tfidf_extractor = TfidfVectorizer(tokenizer=identity_tokenizer, lowercase=False, max_features = 3000)    
sparse_tfidf_domain_list = tfidf_extractor.fit_transform(df_upd['domain_list'])

# %%
mask_test = df_upd['gender_cat']==-1

# %%
tf_idf_matrix = sparse_tfidf_domain_list.todense()[~mask_test]
tf_idf_matrix = pd.DataFrame(tf_idf_matrix)

# %%
df_matrix = df_upd[~mask_test][features]

# %%
tf_idf_matrix.shape
# Out:
# (36138, 3000)

# %%
df_matrix.shape
# Out:
# (36138, 36)

# %%
result = df_matrix.join(tf_idf_matrix)

# %%
X = result.values
y = df_upd[~mask_test]['gender_cat'].values.ravel()

# %%
X.shape, y.shape
# Out:
# ((36138, 3036), (36138,))

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=42)
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((25296, 3036), (10842, 3036), (25296,), (10842,))

# %%
# %%time
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
param_comb = 20

# specify parameters via map
params = {'n_estimators': [200, 300, 400],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'max_depth': [1,3,5,10],
    'min_child_weight': 1,
    'subsample': [0.6, 0.8, 1.0],
    'min_child_weight': [1, 5, 10],
    'gamma': [0.5, 1, 2, 5]}
# Out:
# CPU times: user 63 µs, sys: 151 µs, total: 214 µs
# Wall time: 245 µs

# %%
# %%time
xgb = XGBClassifier(learning_rate=0.1, objective='binary:logistic', random_state=42, n_jobs=-1)

random_search = RandomizedSearchCV(xgb, param_distributions=params, 
                                   n_iter=param_comb, scoring='roc_auc', 
                                   cv=skf, verbose=3, random_state=42 )

random_search.fit(X_train, y_train)

# %% [markdown]
# ## LightGBM

# %%
from scipy import sparse
import lightgbm as lgb
# Out:
# /Users/antonina.goryacheva/anaconda3/lib/python3.7/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'num_leaves': 31,
    'learning_rate': 0.01,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

# %%
lgb_train = lgb.Dataset(X, y.ravel())

# %%
# %%time

res = lgb.cv(params,
             lgb_train,
             num_boost_round=2000,
             nfold=5,
             stratified=True,
             shuffle=True, 
             early_stopping_rounds=100,
             verbose_eval=1)

# %%
num_boost = np.argmax(res['auc-mean'])
num_boost, res['auc-mean'][num_boost], res['auc-stdv'][num_boost]

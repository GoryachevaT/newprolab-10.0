# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Кластеризация

# %% [markdown]
# # K-means

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
plt.figure(figsize=(12, 9))

n_samples = 1500
random_state = 170
X, y = make_blobs(n_samples=n_samples, random_state=random_state)
plt.scatter(X[:, 0], X[:, 1])

# %%
plt.figure(figsize=(12, 12))
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)

# %% [markdown]
# Ограничения Kmeans

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

plt.figure(figsize=(12, 12))

n_samples = 1500
random_state = 170
X, y = make_blobs(n_samples=n_samples, random_state=random_state)

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1])
plt.title("Incorrect Number of Blobs")

# Anisotropicly distributed data
transformation = [[0.60834549, -0.63667341], [-0.40887718, 0.85253229]]
X_aniso = np.dot(X, transformation)

plt.subplot(222)
plt.scatter(X_aniso[:, 0], X_aniso[:, 1])
plt.title("Anisotropicly Distributed Blobs")

# Different variance
X_varied, y_varied = make_blobs(n_samples=n_samples,
                                cluster_std=[1.0, 2.5, 0.5],
                                random_state=random_state)

plt.subplot(223)
plt.scatter(X_varied[:, 0], X_varied[:, 1])
plt.title("Unequal Variance")

#circles
from sklearn.datasets import make_circles
X, y = make_circles(n_samples=n_samples, random_state=random_state)
y_pred = KMeans(n_clusters=2, random_state=random_state).fit_predict(X)

plt.subplot(224)
plt.scatter(X[:, 0], X[:, 1])
plt.title("Circles")


plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

plt.figure(figsize=(12, 12))

n_samples = 1500
random_state = 170
X, y = make_blobs(n_samples=n_samples, random_state=random_state)

# Incorrect number of clusters
y_pred = KMeans(n_clusters=2, random_state=random_state).fit_predict(X)

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("Incorrect Number of Blobs")

# Anisotropicly distributed data
transformation = [[0.60834549, -0.63667341], [-0.40887718, 0.85253229]]
X_aniso = np.dot(X, transformation)
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(X_aniso)

plt.subplot(222)
plt.scatter(X_aniso[:, 0], X_aniso[:, 1], c=y_pred)
plt.title("Anisotropicly Distributed Blobs")

# Different variance
X_varied, y_varied = make_blobs(n_samples=n_samples,
                                cluster_std=[1.0, 2.5, 0.5],
                                random_state=random_state)
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(X_varied)

plt.subplot(223)
plt.scatter(X_varied[:, 0], X_varied[:, 1], c=y_pred)
plt.title("Unequal Variance")

# circles
from sklearn.datasets import make_circles
X, y = make_circles(n_samples=n_samples, random_state=random_state)
y_pred = KMeans(n_clusters=2, random_state=random_state).fit_predict(X)

plt.subplot(224)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("Circles")


plt.show()

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
plt.figure(figsize=(12, 12))

n_samples = 1500
random_state = 170
X, y = make_blobs(n_samples=n_samples, random_state=random_state)

# Incorrect number of clusters
y_pred = DBSCAN(min_samples=25).fit_predict(X)

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("Incorrect Number of Blobs")

# Anisotropicly distributed data
transformation = [[0.60834549, -0.63667341], [-0.40887718, 0.85253229]]
X_aniso = np.dot(X, transformation)
y_pred = DBSCAN(eps=0.2).fit_predict(X_aniso)

plt.subplot(222)
plt.scatter(X_aniso[:, 0], X_aniso[:, 1], c=y_pred)
plt.title("Anisotropicly Distributed Blobs")

# Different variance
X_varied, y_varied = make_blobs(n_samples=n_samples,
                                cluster_std=[1.0, 2.5, 0.5],
                                random_state=random_state)
y_pred = DBSCAN().fit_predict(X_varied)
plt.subplot(223)
plt.scatter(X_varied[:, 0], X_varied[:, 1], c=y_pred)
plt.title("Unequal Variance")

from sklearn.datasets import make_circles
X, y = make_circles(n_samples=n_samples, random_state=random_state)
y_pred = DBSCAN(eps=0.05).fit_predict(X)
plt.subplot(224)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("Circles")

plt.show()

# %% [markdown]
# Поиграем с параметрами

# %%
from sklearn.metrics import silhouette_score
# Out:
# <function sklearn.metrics.cluster.unsupervised.silhouette_score(X, labels, metric='euclidean', sample_size=None, random_state=None, **kwds)>

# %%
X_varied, y_varied = make_blobs(n_samples=n_samples,
                                cluster_std=[1.0, 2.5, 0.5],
                                random_state=random_state)
y_pred = DBSCAN().fit_predict(X_varied)

plt.figure(figsize=(15,9))
plt.scatter(X_varied[:, 0], X_varied[:, 1], c=y_pred)
plt.colorbar()
plt.title("Unequal Variance");

silhouette_score(X_varied, y_pred)
# Out:
# 0.2869451784647595

# %% [markdown]
# # Иерархическая кластеризация

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
y_pred = AgglomerativeClustering(n_clusters=7).fit_predict(X_varied)

plt.figure(figsize=(15,9))
plt.scatter(X_varied[:, 0], X_varied[:, 1], c=y_pred)
plt.title("Unequal Variance")

silhouette_score(X_varied, y_pred)
# Out:
# 0.5775519012737963

# %% [markdown]
# # Понижение размерности

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
df = pd.read_csv('/data/share/TopicModelling/lenta-ru-news_small.csv', usecols=['text','topic'])
#df = pd.read_csv('lenta-ru-news_small.csv', usecols=['text','topic'])
df = df[(df['topic'] == 'Спорт') | (df['topic'] == 'Культура')]
count_vect = CountVectorizer(max_features=5000)
matrix_count = count_vect.fit_transform(df.text).toarray()

# %%
df.topic = df.topic.apply(lambda x: str(x))
df.topic.value_counts()
# Out:
# Спорт       480
# Культура    403
# Name: topic, dtype: int64

# %%
# %%time
from sklearn.preprocessing import OrdinalEncoder
from sklearn.decomposition import PCA

p = PCA(n_components=2)
pca_res = p.fit_transform(matrix_count)
label = OrdinalEncoder(dtype=np.int32).fit_transform(df.topic.fillna(0).values.reshape(-1,1)).reshape(-1)
# Out:
# CPU times: user 1.45 s, sys: 152 ms, total: 1.6 s
# Wall time: 90.2 ms

# %%
p.explained_variance_ratio_
# Out:
# array([0.04963059, 0.02855624])

# %%
from matplotlib import pyplot as plt
plt.figure(figsize = (17,7))
plt.scatter(pca_res[:,0],pca_res[:,1], c=label)

# %%
from sklearn.datasets import load_digits
digits = load_digits()
plt.imshow(digits.images[20], cmap='gray')

# %%
p = PCA(n_components=21)
pca_res = p.fit_transform(digits.data)
#label = OrdinalEncoder(dtype=np.int32).fit_transform(df.topic.fillna(0).values.reshape(-1,1)).reshape(-1)
p.explained_variance_ratio_.sum()
# Out:
# 0.9031911042993159

# %% [markdown]
# t-SNE

# %%
# %%time
from sklearn.manifold import TSNE
t = TSNE(n_components=2, random_state=0)
new = t.fit_transform(matrix_count)
label = OrdinalEncoder().fit_transform(df.topic.fillna(0).values.reshape(-1,1)).reshape(-1)
# Out:
# CPU times: user 23.1 s, sys: 904 ms, total: 24 s
# Wall time: 13.3 s

# %%
t.

# %%
plt.figure(figsize = (17,7))
plt.scatter(new[:,0],new[:,1], c=label)
plt.colorbar()

# %% [markdown]
# UMAP

# %%
# !pip install umap-learn

# %%
# %%time
import umap
emb = umap.UMAP(n_neighbors=5, metric='cosine', min_dist=0.2, random_state=0).fit_transform(matrix_count)
# Out:
# CPU times: user 8.65 s, sys: 1.19 s, total: 9.84 s
# Wall time: 1.9 s

# %%
plt.figure(figsize = (17,7))
plt.scatter(emb[:,0],emb[:,1], c=label)
